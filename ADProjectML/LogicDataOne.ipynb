# %% [markdown]
# # Machine Learning Documentation

# %% [markdown]
# ## Load Data

# %%
#import relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from datetime import datetime
from datetime import date
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

# %%
#loading data
df = pd.read_csv('MockDataV2.csv')
df.head()
# Out:
#    Index  TempIndex ItemNumber StationeryType  \
# 0      1         39      H032        Puncher
# 1      2         19      E032       Exercise
# 2      3         90       T101          Tray
# 3      4         78      S022        Stapler
# 4      5         55      P035            Pen
#
#                        StationeryName  ReorderLevel ReorderQty     UOM  Price  \
# 0               Hole Puncher 3 holes             50    $20.00    Each   12.60
# 1  Exercise Book A4 Hardcover 100 pg            100    $50.00    Each    0.21
# 2                  Trays White InOut             20    $10.00     Set    6.00
# 3                     Stapler No. 28             50    $20.00     Box    3.60
# 4                   Pen Felt Tip Red            100    $50.00   Dozen    2.50
#
#   SupplierName                    Dates      Time  RequisitionQuantity  \
# 0        CHEAP  Monday, January 2, 2017  10:09:45                  144
# 1          WOW  Monday, January 2, 2017   9:00:26                  185
# 2        APLHA  Monday, January 2, 2017  13:02:20                   75
# 3        APLHA  Monday, January 2, 2017  17:04:33                  112
# 4      LOTCASH  Monday, January 2, 2017  13:58:04                  415
#
#    TotalPrice
# 0  $1,814.40
# 1     $38.85
# 2    $450.00
# 3    $403.20
# 4  $1,037.50

# %%
#checking datatypes
df.dtypes
# Out:
# Index                    int64
# TempIndex                int64
# ItemNumber              object
# StationeryType          object
# StationeryName          object
# ReorderLevel             int64
# ReorderQty              object
# UOM                     object
# Price                  float64
# SupplierName            object
# Dates                   object
# Time                    object
# RequisitionQuantity      int64
# TotalPrice              object
# dtype: object

# %% [markdown]
# ### Data Pre-processing

# %%
#adding a new column(TotalPrice_new) for converting TotalPrice into datatype float64.
df['TotalPrice_new'] = df['TotalPrice'].apply(lambda x: x.replace('$','')).apply(lambda x: x.replace(',','')).astype(np.float64)
df
# Out:
#        Index  TempIndex ItemNumber StationeryType  \
# 0          1         39      H032        Puncher
# 1          2         19      E032       Exercise
# 2          3         90       T101          Tray
# 3          4         78      S022        Stapler
# 4          5         55      P035            Pen
# 5          6         27      F023           File
# 6          7         68      R001          Ruler
# 7          8         21      E034       Exercise
# 8          9         53      P033            Pen
# 9         10         18      E031       Exercise
# 10        11         15      E020         Eraser
# 11        12         80      T001          Tacks
# 12        13         40      H033        Puncher
# 13        14         89      T100           Tray
# 14        15         48      P020          Paper
# 15        16          6      C006           Clip
# 16        17         71      S041           Tape
# 17        18         25      F021           File
# 18        19          5      C005           Clip
# 19        20          9      E003       Envelope
# 20        21         79      S023        Stapler
# 21        22          8      E002       Envelope
# 22        23         70      S040           Tape
# 23        24         50      P030            Pen
# 24        25         16      E021         Eraser
# 25        26         51      P031            Pen
# 26        27          5      C005           Clip
# 27        28          8      E002       Envelope
# 28        29         65      P045            Pen
# 29        30         80      T001          Tacks
# ...      ...        ...        ...            ...
# 41970  41971         25      F021           File
# 41971  41972         28      F024           File
# 41972  41973         62      P042            Pen
# 41973  41974         10      E004       Envelope
# 41974  41975         50      P030            Pen
# 41975  41976         63      P043            Pen
# 41976  41977         62      P042            Pen
# 41977  41978         60      P040            Pen
# 41978  41979         55      P035            Pen
# 41979  41980          3      C003           Clip
# 41980  41981         16      E021         Eraser
# 41981  41982         53      P033            Pen
# 41982  41983         16      E021         Eraser
# 41983  41984          8      E002       Envelope
# 41984  41985         66      P046            Pen
# 41985  41986         51      P031            Pen
# 41986  41987         35      H012            Pen
# 41987  41988         90       T101          Tray
# 41988  41989         82      T003          Tacks
# 41989  41990         15      E020         Eraser
# 41990  41991         71      S041           Tape
# 41991  41992         35      H012            Pen
# 41992  41993         50      P030            Pen
# 41993  41994         31      F033           File
# 41994  41995         65      P045            Pen
# 41995  41996         80      T001          Tacks
# 41996  41997         49      P021          Paper
# 41997  41998         77      S021        Stapler
# 41998  41999         45      P014            Pad
# 41999  42000         79      S023        Stapler
#
#                              StationeryName  ReorderLevel ReorderQty      UOM  \
# 0                     Hole Puncher 3 holes             50    $20.00     Each
# 1        Exercise Book A4 Hardcover 100 pg            100    $50.00     Each
# 2                        Trays White InOut             20    $10.00      Set
# 3                           Stapler No. 28             50    $20.00      Box
# 4                         Pen Felt Tip Red            100    $50.00    Dozen
# 5                       File-Brown wo Logo            200   $150.00     Each
# 6                              Ruler 6inch             50    $20.00    Dozen
# 7        Exercise Book A4 Hardcover 200 pg            100    $50.00     Each
# 8                       Pen Felt Tip Black            100    $50.00    Dozen
# 9                     Exercise Book 120 pg            100    $50.00     Each
# 10                             Eraser hard             50    $20.00     Each
# 11                       Thumb Tacks Large             10    $10.00      Box
# 12                 Hole Puncher Adjustable             50    $20.00     Each
# 13                             Trays InOut             20    $10.00      Set
# 14                      Paper Photostat A3            500   $500.00      Box
# 15                       Clips Paper Small             50    $30.00      Box
# 16                   Scotch Tape Dispenser             50    $20.00     Each
# 17                         File-Blue Plain            200   $100.00     Each
# 18                      Clips Paper Medium             50    $30.00      Box
# 19              Envelope Brown 5inchx7inch            600   $400.00     Each
# 20                          Stapler No. 36             50    $20.00      Box
# 21     Envelope Brown 3inchx6inch w Window            600   $400.00     Each
# 22                             Scotch Tape             50    $20.00     Each
# 23                     Pen Ballpoint Black            100    $50.00    Dozen
# 24                             Eraser soft             50    $20.00     Each
# 25                      Pen Ballpoint Blue            100    $50.00    Dozen
# 26                      Clips Paper Medium             50    $30.00      Box
# 27     Envelope Brown 3inchx6inch w Window            600   $400.00     Each
# 28                                Pencil B            100    $50.00    Dozen
# 29                       Thumb Tacks Large             10    $10.00      Box
# ...                                     ...           ...        ...      ...
# 41970                      File-Blue Plain            200        100    Each
# 41971                 File-Brown with Logo            200        150    Each
# 41972                            Pencil 2B            100         50   Dozen
# 41973  Envelope Brown 5inchx7inch w Window            600        400    Each
# 41974                  Pen Ballpoint Black            100         50   Dozen
# 41975            Pencil 2B with Eraser End            100         50   Dozen
# 41976                            Pencil 2B            100         50   Dozen
# 41977          Pen Whiteboard Marker Green            100         50     Box
# 41978                     Pen Felt Tip Red            100         50   Dozen
# 41979                  Clips Double 34inch             50         30   Dozen
# 41980                          Eraser soft             50         20    Each
# 41981                   Pen Felt Tip Black            100         50   Dozen
# 41982                          Eraser soft             50         20    Each
# 41983  Envelope Brown 3inchx6inch w Window            600        400    Each
# 41984             Pencil B with Eraser End            100         50   Dozen
# 41985                   Pen Ballpoint Blue            100         50   Dozen
# 41986                    Highlighter Green            100         80     Box
# 41987                    Trays White InOut             20         10     Set
# 41988                    Thumb Tacks Small             10         10     Box
# 41989                          Eraser hard             50         20    Each
# 41990                Scotch Tape Dispenser             50         20    Each
# 41991                    Highlighter Green            100         80     Box
# 41992                  Pen Ballpoint Black            100         50   Dozen
# 41993                 Folder Plastic Green            200        150    Each
# 41994                             Pencil B            100         50   Dozen
# 41995                    Thumb Tacks Large             10         10     Box
# 41996                   Paper Photostat A4            500        500     Box
# 41997                       Stapler No. 36             50         20    Each
# 41998          Pad Postit Memo 2inchx4inch            100         60  Packet
# 41999                       Stapler No. 36             50         20     Box
#
#        Price SupplierName                      Dates      Time  \
# 0      12.60        CHEAP    Monday, January 2, 2017  10:09:45
# 1       0.21          WOW    Monday, January 2, 2017   9:00:26
# 2       6.00        APLHA    Monday, January 2, 2017  13:02:20
# 3       3.60        APLHA    Monday, January 2, 2017  17:04:33
# 4       2.50      LOTCASH    Monday, January 2, 2017  13:58:04
# 5       2.10        APLHA    Monday, January 2, 2017  15:00:12
# 6       2.50        APLHA    Monday, January 2, 2017  14:52:04
# 7       0.27        BANES    Monday, January 2, 2017  16:02:09
# 8       2.50       RANDOM    Monday, January 2, 2017  11:11:35
# 9       0.26        BANES    Monday, January 2, 2017  10:30:00
# 10      0.40      LOTCASH    Monday, January 2, 2017  16:20:41
# 11      2.00        BANES    Monday, January 2, 2017  16:11:20
# 12     15.30        CHEAP    Monday, January 2, 2017  17:00:26
# 13      6.00        CHEAP    Monday, January 2, 2017   9:15:58
# 14     13.00        APLHA    Monday, January 2, 2017  10:04:41
# 15      1.20        BANES    Monday, January 2, 2017  11:08:30
# 16      2.30      LOTCASH    Monday, January 2, 2017  10:09:40
# 17      2.30          ISS    Monday, January 2, 2017  12:42:14
# 18      1.50        APLHA    Monday, January 2, 2017  12:06:36
# 19      1.60      LOTCASH    Monday, January 2, 2017  13:15:06
# 20      3.90        OMEGA    Monday, January 2, 2017  12:40:03
# 21      1.10        OMEGA    Monday, January 2, 2017  11:28:06
# 22      1.20        OMEGA    Monday, January 2, 2017   9:53:08
# 23      2.50       RANDOM    Monday, January 2, 2017  10:54:43
# 24      0.30        FIEND    Monday, January 2, 2017  17:40:00
# 25      2.50        OMEGA    Monday, January 2, 2017   9:10:10
# 26      1.50        APLHA    Monday, January 2, 2017  13:02:04
# 27      1.10        OMEGA    Monday, January 2, 2017  16:56:44
# 28      1.00      LOTCASH    Monday, January 2, 2017  12:32:31
# 29      2.00        BANES    Monday, January 2, 2017  10:00:08
# ...      ...          ...                        ...       ...
# 41970   2.30          ISS  Thursday, August 15, 2019  11:20:08
# 41971   2.30          ISS  Thursday, August 15, 2019  12:40:00
# 41972   1.20        CHEAP  Thursday, August 15, 2019  14:04:00
# 41973   1.70          ISS  Thursday, August 15, 2019  14:00:41
# 41974   2.50       RANDOM  Thursday, August 15, 2019  10:17:26
# 41975   1.80    FANTASTIC  Thursday, August 15, 2019  10:18:14
# 41976   1.20        CHEAP  Thursday, August 15, 2019  12:37:06
# 41977   7.20    FANTASTIC  Thursday, August 15, 2019   9:16:17
# 41978   2.50      LOTCASH  Thursday, August 15, 2019  16:02:30
# 41979   0.90       RANDOM  Thursday, August 15, 2019  15:22:20
# 41980   0.30        FIEND  Thursday, August 15, 2019  15:12:09
# 41981   2.50       RANDOM  Thursday, August 15, 2019  11:35:19
# 41982   0.30        FIEND  Thursday, August 15, 2019  12:29:37
# 41983   1.10        OMEGA  Thursday, August 15, 2019  17:28:24
# 41984   1.20      LOTCASH  Thursday, August 15, 2019  16:25:57
# 41985   2.50        OMEGA  Thursday, August 15, 2019  12:45:38
# 41986   5.60          WOW  Thursday, August 15, 2019  11:59:19
# 41987   6.00        APLHA  Thursday, August 15, 2019  14:42:21
# 41988   1.00      LOTCASH  Thursday, August 15, 2019   9:17:19
# 41989   0.40      LOTCASH  Thursday, August 15, 2019  17:25:56
# 41990   2.30      LOTCASH  Thursday, August 15, 2019  16:04:10
# 41991   5.60          WOW  Thursday, August 15, 2019  17:56:38
# 41992   2.50       RANDOM  Thursday, August 15, 2019  17:12:39
# 41993   4.00       RANDOM  Thursday, August 15, 2019  10:13:53
# 41994   1.00      LOTCASH  Thursday, August 15, 2019  12:21:37
# 41995   2.00        BANES  Thursday, August 15, 2019  14:59:03
# 41996   8.00          WOW  Thursday, August 15, 2019  10:00:37
# 41997   3.90        FIEND  Thursday, August 15, 2019  16:41:19
# 41998   6.20        APLHA  Thursday, August 15, 2019  11:40:50
# 41999   3.90        OMEGA  Thursday, August 15, 2019  16:10:46
#
#        RequisitionQuantity   TotalPrice  TotalPrice_new
# 0                      144   $1,814.40          1814.40
# 1                      185      $38.85            38.85
# 2                       75     $450.00           450.00
# 3                      112     $403.20           403.20
# 4                      415   $1,037.50          1037.50
# 5                     1440   $3,024.00          3024.00
# 6                       48     $120.00           120.00
# 7                      300      $81.00            81.00
# 8                      320     $800.00           800.00
# 9                      485     $126.10           126.10
# 10                     190      $76.00            76.00
# 11                      53     $106.00           106.00
# 12                     128   $1,958.40          1958.40
# 13                      57     $342.00           342.00
# 14                    2000  $26,000.00         26000.00
# 15                     114     $136.80           136.80
# 16                     126     $289.80           289.80
# 17                     210     $483.00           483.00
# 18                     234     $351.00           351.00
# 19                     480     $768.00           768.00
# 20                     152     $592.80           592.80
# 21                    1880   $2,068.00          2068.00
# 22                      24      $28.80            28.80
# 23                     160     $400.00           400.00
# 24                     142      $42.60            42.60
# 25                     490   $1,225.00          1225.00
# 26                     174     $261.00           261.00
# 27                     400     $440.00           440.00
# 28                     465     $465.00           465.00
# 29                      86     $172.00           172.00
# ...                    ...          ...             ...
# 41970                  500         1150         1150.00
# 41971                 1320         3036         3036.00
# 41972                  130          156          156.00
# 41973                  560          952          952.00
# 41974                  395        987.5          987.50
# 41975                  335          603          603.00
# 41976                  365          438          438.00
# 41977                  240         1728         1728.00
# 41978                  155        387.5          387.50
# 41979                   75         67.5           67.50
# 41980                  154         46.2           46.20
# 41981                  160          400          400.00
# 41982                  130           39           39.00
# 41983                 2440         2684         2684.00
# 41984                  420          504          504.00
# 41985                  145        362.5          362.50
# 41986                  328       1836.8         1836.80
# 41987                   22          132          132.00
# 41988                   47           47           47.00
# 41989                  140           56           56.00
# 41990                   90          207          207.00
# 41991                  728       4076.8         4076.80
# 41992                  155        387.5          387.50
# 41993                  150          600          600.00
# 41994                  240          240          240.00
# 41995                   14           28           28.00
# 41996                  700         5600         5600.00
# 41997                  108        421.2          421.20
# 41998                  534       3310.8         3310.80
# 41999                   52        202.8          202.80
#
# [42000 rows x 15 columns]

# %%
#extract the necessary columns
df_extracted = df.iloc[:,[1,2,3,4,9,10,12,13,14]]
df_extracted.head()
# Out:
#    TempIndex ItemNumber StationeryType                      StationeryName  \
# 0         39      H032        Puncher                Hole Puncher 3 holes
# 1         19      E032       Exercise   Exercise Book A4 Hardcover 100 pg
# 2         90       T101          Tray                   Trays White InOut
# 3         78      S022        Stapler                      Stapler No. 28
# 4         55      P035            Pen                    Pen Felt Tip Red
#
#   SupplierName                    Dates  RequisitionQuantity  TotalPrice  \
# 0        CHEAP  Monday, January 2, 2017                  144  $1,814.40
# 1          WOW  Monday, January 2, 2017                  185     $38.85
# 2        APLHA  Monday, January 2, 2017                   75    $450.00
# 3        APLHA  Monday, January 2, 2017                  112    $403.20
# 4      LOTCASH  Monday, January 2, 2017                  415  $1,037.50
#
#    TotalPrice_new
# 0         1814.40
# 1           38.85
# 2          450.00
# 3          403.20
# 4         1037.50

# %%
df_extracted['Dates'] = df_extracted['Dates'].astype('datetime64[ns]')
df_extracted
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        TempIndex ItemNumber StationeryType  \
# 0             39      H032        Puncher
# 1             19      E032       Exercise
# 2             90       T101          Tray
# 3             78      S022        Stapler
# 4             55      P035            Pen
# 5             27      F023           File
# 6             68      R001          Ruler
# 7             21      E034       Exercise
# 8             53      P033            Pen
# 9             18      E031       Exercise
# 10            15      E020         Eraser
# 11            80      T001          Tacks
# 12            40      H033        Puncher
# 13            89      T100           Tray
# 14            48      P020          Paper
# 15             6      C006           Clip
# 16            71      S041           Tape
# 17            25      F021           File
# 18             5      C005           Clip
# 19             9      E003       Envelope
# 20            79      S023        Stapler
# 21             8      E002       Envelope
# 22            70      S040           Tape
# 23            50      P030            Pen
# 24            16      E021         Eraser
# 25            51      P031            Pen
# 26             5      C005           Clip
# 27             8      E002       Envelope
# 28            65      P045            Pen
# 29            80      T001          Tacks
# ...          ...        ...            ...
# 41970         25      F021           File
# 41971         28      F024           File
# 41972         62      P042            Pen
# 41973         10      E004       Envelope
# 41974         50      P030            Pen
# 41975         63      P043            Pen
# 41976         62      P042            Pen
# 41977         60      P040            Pen
# 41978         55      P035            Pen
# 41979          3      C003           Clip
# 41980         16      E021         Eraser
# 41981         53      P033            Pen
# 41982         16      E021         Eraser
# 41983          8      E002       Envelope
# 41984         66      P046            Pen
# 41985         51      P031            Pen
# 41986         35      H012            Pen
# 41987         90       T101          Tray
# 41988         82      T003          Tacks
# 41989         15      E020         Eraser
# 41990         71      S041           Tape
# 41991         35      H012            Pen
# 41992         50      P030            Pen
# 41993         31      F033           File
# 41994         65      P045            Pen
# 41995         80      T001          Tacks
# 41996         49      P021          Paper
# 41997         77      S021        Stapler
# 41998         45      P014            Pad
# 41999         79      S023        Stapler
#
#                              StationeryName SupplierName      Dates  \
# 0                     Hole Puncher 3 holes         CHEAP 2017-01-02
# 1        Exercise Book A4 Hardcover 100 pg           WOW 2017-01-02
# 2                        Trays White InOut         APLHA 2017-01-02
# 3                           Stapler No. 28         APLHA 2017-01-02
# 4                         Pen Felt Tip Red       LOTCASH 2017-01-02
# 5                       File-Brown wo Logo         APLHA 2017-01-02
# 6                              Ruler 6inch         APLHA 2017-01-02
# 7        Exercise Book A4 Hardcover 200 pg         BANES 2017-01-02
# 8                       Pen Felt Tip Black        RANDOM 2017-01-02
# 9                     Exercise Book 120 pg         BANES 2017-01-02
# 10                             Eraser hard       LOTCASH 2017-01-02
# 11                       Thumb Tacks Large         BANES 2017-01-02
# 12                 Hole Puncher Adjustable         CHEAP 2017-01-02
# 13                             Trays InOut         CHEAP 2017-01-02
# 14                      Paper Photostat A3         APLHA 2017-01-02
# 15                       Clips Paper Small         BANES 2017-01-02
# 16                   Scotch Tape Dispenser       LOTCASH 2017-01-02
# 17                         File-Blue Plain           ISS 2017-01-02
# 18                      Clips Paper Medium         APLHA 2017-01-02
# 19              Envelope Brown 5inchx7inch       LOTCASH 2017-01-02
# 20                          Stapler No. 36         OMEGA 2017-01-02
# 21     Envelope Brown 3inchx6inch w Window         OMEGA 2017-01-02
# 22                             Scotch Tape         OMEGA 2017-01-02
# 23                     Pen Ballpoint Black        RANDOM 2017-01-02
# 24                             Eraser soft         FIEND 2017-01-02
# 25                      Pen Ballpoint Blue         OMEGA 2017-01-02
# 26                      Clips Paper Medium         APLHA 2017-01-02
# 27     Envelope Brown 3inchx6inch w Window         OMEGA 2017-01-02
# 28                                Pencil B       LOTCASH 2017-01-02
# 29                       Thumb Tacks Large         BANES 2017-01-02
# ...                                     ...          ...        ...
# 41970                      File-Blue Plain           ISS 2019-08-15
# 41971                 File-Brown with Logo           ISS 2019-08-15
# 41972                            Pencil 2B         CHEAP 2019-08-15
# 41973  Envelope Brown 5inchx7inch w Window           ISS 2019-08-15
# 41974                  Pen Ballpoint Black        RANDOM 2019-08-15
# 41975            Pencil 2B with Eraser End     FANTASTIC 2019-08-15
# 41976                            Pencil 2B         CHEAP 2019-08-15
# 41977          Pen Whiteboard Marker Green     FANTASTIC 2019-08-15
# 41978                     Pen Felt Tip Red       LOTCASH 2019-08-15
# 41979                  Clips Double 34inch        RANDOM 2019-08-15
# 41980                          Eraser soft         FIEND 2019-08-15
# 41981                   Pen Felt Tip Black        RANDOM 2019-08-15
# 41982                          Eraser soft         FIEND 2019-08-15
# 41983  Envelope Brown 3inchx6inch w Window         OMEGA 2019-08-15
# 41984             Pencil B with Eraser End       LOTCASH 2019-08-15
# 41985                   Pen Ballpoint Blue         OMEGA 2019-08-15
# 41986                    Highlighter Green           WOW 2019-08-15
# 41987                    Trays White InOut         APLHA 2019-08-15
# 41988                    Thumb Tacks Small       LOTCASH 2019-08-15
# 41989                          Eraser hard       LOTCASH 2019-08-15
# 41990                Scotch Tape Dispenser       LOTCASH 2019-08-15
# 41991                    Highlighter Green           WOW 2019-08-15
# 41992                  Pen Ballpoint Black        RANDOM 2019-08-15
# 41993                 Folder Plastic Green        RANDOM 2019-08-15
# 41994                             Pencil B       LOTCASH 2019-08-15
# 41995                    Thumb Tacks Large         BANES 2019-08-15
# 41996                   Paper Photostat A4           WOW 2019-08-15
# 41997                       Stapler No. 36         FIEND 2019-08-15
# 41998          Pad Postit Memo 2inchx4inch         APLHA 2019-08-15
# 41999                       Stapler No. 36         OMEGA 2019-08-15
#
#        RequisitionQuantity   TotalPrice  TotalPrice_new
# 0                      144   $1,814.40          1814.40
# 1                      185      $38.85            38.85
# 2                       75     $450.00           450.00
# 3                      112     $403.20           403.20
# 4                      415   $1,037.50          1037.50
# 5                     1440   $3,024.00          3024.00
# 6                       48     $120.00           120.00
# 7                      300      $81.00            81.00
# 8                      320     $800.00           800.00
# 9                      485     $126.10           126.10
# 10                     190      $76.00            76.00
# 11                      53     $106.00           106.00
# 12                     128   $1,958.40          1958.40
# 13                      57     $342.00           342.00
# 14                    2000  $26,000.00         26000.00
# 15                     114     $136.80           136.80
# 16                     126     $289.80           289.80
# 17                     210     $483.00           483.00
# 18                     234     $351.00           351.00
# 19                     480     $768.00           768.00
# 20                     152     $592.80           592.80
# 21                    1880   $2,068.00          2068.00
# 22                      24      $28.80            28.80
# 23                     160     $400.00           400.00
# 24                     142      $42.60            42.60
# 25                     490   $1,225.00          1225.00
# 26                     174     $261.00           261.00
# 27                     400     $440.00           440.00
# 28                     465     $465.00           465.00
# 29                      86     $172.00           172.00
# ...                    ...          ...             ...
# 41970                  500         1150         1150.00
# 41971                 1320         3036         3036.00
# 41972                  130          156          156.00
# 41973                  560          952          952.00
# 41974                  395        987.5          987.50
# 41975                  335          603          603.00
# 41976                  365          438          438.00
# 41977                  240         1728         1728.00
# 41978                  155        387.5          387.50
# 41979                   75         67.5           67.50
# 41980                  154         46.2           46.20
# 41981                  160          400          400.00
# 41982                  130           39           39.00
# 41983                 2440         2684         2684.00
# 41984                  420          504          504.00
# 41985                  145        362.5          362.50
# 41986                  328       1836.8         1836.80
# 41987                   22          132          132.00
# 41988                   47           47           47.00
# 41989                  140           56           56.00
# 41990                   90          207          207.00
# 41991                  728       4076.8         4076.80
# 41992                  155        387.5          387.50
# 41993                  150          600          600.00
# 41994                  240          240          240.00
# 41995                   14           28           28.00
# 41996                  700         5600         5600.00
# 41997                  108        421.2          421.20
# 41998                  534       3310.8         3310.80
# 41999                   52        202.8          202.80
#
# [42000 rows x 9 columns]

# %%
df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Data columns (total 9 columns):
# TempIndex              42000 non-null int64
# ItemNumber             42000 non-null object
# StationeryType         42000 non-null object
# StationeryName         42000 non-null object
# SupplierName           42000 non-null object
# Dates                  42000 non-null datetime64[ns]
# RequisitionQuantity    42000 non-null int64
# TotalPrice             42000 non-null object
# TotalPrice_new         42000 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 2.9+ MB

# %%
#list down all the stationery types
TypeArray = df_extracted.StationeryType.unique()
TypeArray

#replace stationery type name with an integer 
def Trans_StationeryType(x):
    for y in range(0,len(TypeArray)):
        if x == TypeArray[y]:
            return y+1

#adding a new column for the stationery type in terms of integer
df_extracted['TransStationeryType'] = df_extracted['StationeryType'].apply(Trans_StationeryType)
df_extracted.head()
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#    TempIndex ItemNumber StationeryType                      StationeryName  \
# 0         39      H032        Puncher                Hole Puncher 3 holes
# 1         19      E032       Exercise   Exercise Book A4 Hardcover 100 pg
# 2         90       T101          Tray                   Trays White InOut
# 3         78      S022        Stapler                      Stapler No. 28
# 4         55      P035            Pen                    Pen Felt Tip Red
#
#   SupplierName      Dates  RequisitionQuantity  TotalPrice  TotalPrice_new  \
# 0        CHEAP 2017-01-02                  144  $1,814.40          1814.40
# 1          WOW 2017-01-02                  185     $38.85            38.85
# 2        APLHA 2017-01-02                   75    $450.00           450.00
# 3        APLHA 2017-01-02                  112    $403.20           403.20
# 4      LOTCASH 2017-01-02                  415  $1,037.50          1037.50
#
#    TransStationeryType
# 0                    1
# 1                    2
# 2                    3
# 3                    4
# 4                    5

# %%
#groupby Stationery Name & Type & Supplier and sum the quantity and total price
df_new = df_extracted.groupby(['StationeryName','StationeryType','SupplierName']).agg({'RequisitionQuantity':'sum','TotalPrice_new':'sum'}) 
df_new
# Out:
#                                                                   RequisitionQuantity  \
# StationeryName                       StationeryType SupplierName
# Clips Double 1inch                   Clip           FIEND                       76173
# Clips Double 2inch                   Clip           BANES                       80574
# Clips Double 34inch                  Clip           RANDOM                      77469
# Clips Paper Large                    Clip           APLHA                       77700
# Clips Paper Medium                   Clip           APLHA                       81249
# Clips Paper Small                    Clip           BANES                       77007
# Envelope Brown 3inchx6inch           Envelope       ISS                        986360
# Envelope Brown 3inchx6inch w Window  Envelope       OMEGA                      961360
# Envelope Brown 5inchx7inch           Envelope       LOTCASH                   1067880
# Envelope Brown 5inchx7inch w Window  Envelope       ISS                        993800
# Envelope White 3inchx6inch           Envelope       ISS                       1017680
# Envelope White 3inchx6inch w Window  Envelope       OMEGA                     1065320
# Envelope White 5inchx7inch           Envelope       APLHA                      942400
# Envelope White 5inchx7inch w Window  Envelope       BANES                     1038280
# Eraser hard                          Eraser         LOTCASH                     49498
# Eraser soft                          Eraser         FIEND                       50156
# Exercise Book 100 pg                 Exercise       OMEGA                      126600
# Exercise Book 120 pg                 Exercise       BANES                      131060
# Exercise Book A4 Hardcover 100 pg    Exercise       WOW                        137730
# Exercise Book A4 Hardcover 120 pg    Exercise       BANES                      120180
# Exercise Book A4 Hardcover 200 pg    Exercise       BANES                      128825
# Exercise Book Hardcover 100 pg       Exercise       BANES                      123020
# Exercise Book Hardcover 120 pg       Exercise       ISS                        119290
# File Separator                       File           OMEGA                      128015
# File-Blue Plain                      File           ISS                        259560
# File-Blue with Logo                  File           WOW                        285060
# File-Brown with Logo                 File           ISS                        359205
# File-Brown wo Logo                   File           APLHA                      396825
# Folder Plastic Blue                  File           OMEGA                      408090
# Folder Plastic Clear                 File           BANES                      363045
# ...                                                                               ...
# Pen Whiteboard Marker Red            Pen            FANTASTIC                  132185
# Pencil 2B                            Pen            CHEAP                      136075
# Pencil 2B with Eraser End            Pen            FANTASTIC                  134160
# Pencil 4H                            Pen            APLHA                      126145
# Pencil B                             Pen            LOTCASH                    126605
# Pencil B with Eraser End             Pen            LOTCASH                    130295
# Ruler 12inch                         Ruler          FANTASTIC                   53186
# Ruler 6inch                          Ruler          APLHA                       52972
# Scissors                             Scissors       LOTCASH                     51728
# Scotch Tape                          Tape           OMEGA                       51822
# Scotch Tape Dispenser                Tape           LOTCASH                     54216
# Sharpener                            Sharpener      APLHA                       53726
# Shorthand Book 100 pg                Shorthand      FANTASTIC                  209576
# Shorthand Book 120 pg                Shorthand      ISS                        205184
# Shorthand Book 80 pg                 Shorthand      BANES                      203192
# Stapler No. 28                       Stapler        APLHA                       50380
#                                                     CHEAP                       49716
# Stapler No. 36                       Stapler        FIEND                       52914
#                                                     OMEGA                       51320
# Thumb Tacks Large                    Tacks          BANES                       23516
# Thumb Tacks Medium                   Tacks          WOW                         26536
# Thumb Tacks Small                    Tacks          LOTCASH                     25156
# Transparency Blue                    Tparency       FANTASTIC                  528340
# Transparency Clear                   Tparency       LOTCASH                   1055080
# Transparency Cover 3M                Tparency       FIEND                     1067400
# Transparency Green                   Tparency       LOTCASH                    440720
# Transparency Red                     Tparency       LOTCASH                    523720
# Transparency Reverse Blue            Tparency       FANTASTIC                  516320
# Trays InOut                          Tray           CHEAP                       23804
# Trays White InOut                    Tray           APLHA                       23469
#
#                                                                   TotalPrice_new
# StationeryName                       StationeryType SupplierName
# Clips Double 1inch                   Clip           FIEND               76173.00
# Clips Double 2inch                   Clip           BANES               96688.80
# Clips Double 34inch                  Clip           RANDOM              69722.10
# Clips Paper Large                    Clip           APLHA              155400.00
# Clips Paper Medium                   Clip           APLHA              121873.50
# Clips Paper Small                    Clip           BANES               92408.40
# Envelope Brown 3inchx6inch           Envelope       ISS                986360.00
# Envelope Brown 3inchx6inch w Window  Envelope       OMEGA             1057496.00
# Envelope Brown 5inchx7inch           Envelope       LOTCASH           1708608.00
# Envelope Brown 5inchx7inch w Window  Envelope       ISS               1689460.00
# Envelope White 3inchx6inch           Envelope       ISS               1017680.00
# Envelope White 3inchx6inch w Window  Envelope       OMEGA             1171852.00
# Envelope White 5inchx7inch           Envelope       APLHA             1507840.00
# Envelope White 5inchx7inch w Window  Envelope       BANES             1765076.00
# Eraser hard                          Eraser         LOTCASH             19799.20
# Eraser soft                          Eraser         FIEND               15046.80
# Exercise Book 100 pg                 Exercise       OMEGA               27852.00
# Exercise Book 120 pg                 Exercise       BANES               34075.60
# Exercise Book A4 Hardcover 100 pg    Exercise       WOW                 28923.30
# Exercise Book A4 Hardcover 120 pg    Exercise       BANES               26439.60
# Exercise Book A4 Hardcover 200 pg    Exercise       BANES               34782.75
# Exercise Book Hardcover 100 pg       Exercise       BANES               61510.00
# Exercise Book Hardcover 120 pg       Exercise       ISS                 66802.40
# File Separator                       File           OMEGA              256030.00
# File-Blue Plain                      File           ISS                596988.00
# File-Blue with Logo                  File           WOW                655638.00
# File-Brown with Logo                 File           ISS                826171.50
# File-Brown wo Logo                   File           APLHA              833332.50
# Folder Plastic Blue                  File           OMEGA             1632360.00
# Folder Plastic Clear                 File           BANES             1452180.00
# ...                                                                          ...
# Pen Whiteboard Marker Red            Pen            FANTASTIC          951732.00
# Pencil 2B                            Pen            CHEAP              163290.00
# Pencil 2B with Eraser End            Pen            FANTASTIC          241488.00
# Pencil 4H                            Pen            APLHA              290133.50
# Pencil B                             Pen            LOTCASH            126605.00
# Pencil B with Eraser End             Pen            LOTCASH            156354.00
# Ruler 12inch                         Ruler          FANTASTIC          186151.00
# Ruler 6inch                          Ruler          APLHA              132430.00
# Scissors                             Scissors       LOTCASH            206912.00
# Scotch Tape                          Tape           OMEGA               62186.40
# Scotch Tape Dispenser                Tape           LOTCASH            124696.80
# Sharpener                            Sharpener      APLHA               53726.00
# Shorthand Book 100 pg                Shorthand      FANTASTIC          104788.00
# Shorthand Book 120 pg                Shorthand      ISS                123110.40
# Shorthand Book 80 pg                 Shorthand      BANES               81276.80
# Stapler No. 28                       Stapler        APLHA              181368.00
#                                                     CHEAP              178977.60
# Stapler No. 36                       Stapler        FIEND              206364.60
#                                                     OMEGA              200148.00
# Thumb Tacks Large                    Tacks          BANES               47032.00
# Thumb Tacks Medium                   Tacks          WOW                 39804.00
# Thumb Tacks Small                    Tacks          LOTCASH             25156.00
# Transparency Blue                    Tparency       FANTASTIC          739676.00
# Transparency Clear                   Tparency       LOTCASH           1477112.00
# Transparency Cover 3M                Tparency       FIEND             1494360.00
# Transparency Green                   Tparency       LOTCASH            617008.00
# Transparency Red                     Tparency       LOTCASH            733208.00
# Transparency Reverse Blue            Tparency       FANTASTIC          722848.00
# Trays InOut                          Tray           CHEAP              142824.00
# Trays White InOut                    Tray           APLHA              140814.00
#
# [90 rows x 2 columns]

# %%
df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Data columns (total 10 columns):
# TempIndex              42000 non-null int64
# ItemNumber             42000 non-null object
# StationeryType         42000 non-null object
# StationeryName         42000 non-null object
# SupplierName           42000 non-null object
# Dates                  42000 non-null datetime64[ns]
# RequisitionQuantity    42000 non-null int64
# TotalPrice             42000 non-null object
# TotalPrice_new         42000 non-null float64
# TransStationeryType    42000 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %%
df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match('Transparency Green')] 
df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal())
df_filterByValue
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        TempIndex ItemNumber StationeryType       StationeryName SupplierName  \
# 102           85      T022       Tparency   Transparency Green       LOTCASH
# 130           85      T022       Tparency   Transparency Green       LOTCASH
# 134           85      T022       Tparency   Transparency Green       LOTCASH
# 166           85      T022       Tparency   Transparency Green       LOTCASH
# 233           85      T022       Tparency   Transparency Green       LOTCASH
# 342           85      T022       Tparency   Transparency Green       LOTCASH
# 489           85      T022       Tparency   Transparency Green       LOTCASH
# 508           85      T022       Tparency   Transparency Green       LOTCASH
# 519           85      T022       Tparency   Transparency Green       LOTCASH
# 660           85      T022       Tparency   Transparency Green       LOTCASH
# 903           85      T022       Tparency   Transparency Green       LOTCASH
# 944           85      T022       Tparency   Transparency Green       LOTCASH
# 1001          85      T022       Tparency   Transparency Green       LOTCASH
# 1005          85      T022       Tparency   Transparency Green       LOTCASH
# 1045          85      T022       Tparency   Transparency Green       LOTCASH
# 1193          85      T022       Tparency   Transparency Green       LOTCASH
# 1228          85      T022       Tparency   Transparency Green       LOTCASH
# 1293          85      T022       Tparency   Transparency Green       LOTCASH
# 1629          85      T022       Tparency   Transparency Green       LOTCASH
# 1660          85      T022       Tparency   Transparency Green       LOTCASH
# 1728          85      T022       Tparency   Transparency Green       LOTCASH
# 1770          85      T022       Tparency   Transparency Green       LOTCASH
# 2028          85      T022       Tparency   Transparency Green       LOTCASH
# 2040          85      T022       Tparency   Transparency Green       LOTCASH
# 2076          85      T022       Tparency   Transparency Green       LOTCASH
# 2269          85      T022       Tparency   Transparency Green       LOTCASH
# 2282          85      T022       Tparency   Transparency Green       LOTCASH
# 2447          85      T022       Tparency   Transparency Green       LOTCASH
# 2448          85      T022       Tparency   Transparency Green       LOTCASH
# 2453          85      T022       Tparency   Transparency Green       LOTCASH
# ...          ...        ...            ...                  ...          ...
# 38287         85      T022       Tparency   Transparency Green       LOTCASH
# 38479         85      T022       Tparency   Transparency Green       LOTCASH
# 38521         85      T022       Tparency   Transparency Green       LOTCASH
# 38617         85      T022       Tparency   Transparency Green       LOTCASH
# 38638         85      T022       Tparency   Transparency Green       LOTCASH
# 38697         85      T022       Tparency   Transparency Green       LOTCASH
# 38700         85      T022       Tparency   Transparency Green       LOTCASH
# 38739         85      T022       Tparency   Transparency Green       LOTCASH
# 38766         85      T022       Tparency   Transparency Green       LOTCASH
# 39436         85      T022       Tparency   Transparency Green       LOTCASH
# 39441         85      T022       Tparency   Transparency Green       LOTCASH
# 39702         85      T022       Tparency   Transparency Green       LOTCASH
# 39729         85      T022       Tparency   Transparency Green       LOTCASH
# 39899         85      T022       Tparency   Transparency Green       LOTCASH
# 39903         85      T022       Tparency   Transparency Green       LOTCASH
# 40120         85      T022       Tparency   Transparency Green       LOTCASH
# 40146         85      T022       Tparency   Transparency Green       LOTCASH
# 40524         85      T022       Tparency   Transparency Green       LOTCASH
# 40549         85      T022       Tparency   Transparency Green       LOTCASH
# 40684         85      T022       Tparency   Transparency Green       LOTCASH
# 40810         85      T022       Tparency   Transparency Green       LOTCASH
# 40839         85      T022       Tparency   Transparency Green       LOTCASH
# 40955         85      T022       Tparency   Transparency Green       LOTCASH
# 41109         85      T022       Tparency   Transparency Green       LOTCASH
# 41187         85      T022       Tparency   Transparency Green       LOTCASH
# 41253         85      T022       Tparency   Transparency Green       LOTCASH
# 41426         85      T022       Tparency   Transparency Green       LOTCASH
# 41548         85      T022       Tparency   Transparency Green       LOTCASH
# 41743         85      T022       Tparency   Transparency Green       LOTCASH
# 41790         85      T022       Tparency   Transparency Green       LOTCASH
#
#            Dates  RequisitionQuantity  TotalPrice  TotalPrice_new  \
# 102   2017-01-03                  860  $1,204.00           1204.0
# 130   2017-01-04                  720  $1,008.00           1008.0
# 134   2017-01-04                  840  $1,176.00           1176.0
# 166   2017-01-04                  740  $1,036.00           1036.0
# 233   2017-01-05                  580    $812.00            812.0
# 342   2017-01-09                 1440  $2,016.00           2016.0
# 489   2017-01-11                  900  $1,260.00           1260.0
# 508   2017-01-12                  360    $504.00            504.0
# 519   2017-01-12                  980  $1,372.00           1372.0
# 660   2017-01-16                 1780  $2,492.00           2492.0
# 903   2017-01-20                  320    $448.00            448.0
# 944   2017-01-20                  600    $840.00            840.0
# 1001  2017-01-23                  840  $1,176.00           1176.0
# 1005  2017-01-23                 1480  $2,072.00           2072.0
# 1045  2017-01-24                 1500  $2,100.00           2100.0
# 1193  2017-01-26                 1640  $2,296.00           2296.0
# 1228  2017-01-26                 1700  $2,380.00           2380.0
# 1293  2017-01-27                  780  $1,092.00           1092.0
# 1629  2017-02-06                 1440  $2,016.00           2016.0
# 1660  2017-02-06                 1280  $1,792.00           1792.0
# 1728  2017-02-07                  720  $1,008.00           1008.0
# 1770  2017-02-08                 1980  $2,772.00           2772.0
# 2028  2017-02-14                  200    $280.00            280.0
# 2040  2017-02-14                 1680  $2,352.00           2352.0
# 2076  2017-02-15                  840  $1,176.00           1176.0
# 2269  2017-02-21                  980  $1,372.00           1372.0
# 2282  2017-02-21                  840  $1,176.00           1176.0
# 2447  2017-02-23                  980  $1,372.00           1372.0
# 2448  2017-02-23                  660    $924.00            924.0
# 2453  2017-02-24                 1480  $2,072.00           2072.0
# ...          ...                  ...         ...             ...
# 38287 2019-05-23                 1040        1456          1456.0
# 38479 2019-05-28                 1080        1512          1512.0
# 38521 2019-05-29                  500         700           700.0
# 38617 2019-05-30                  380         532           532.0
# 38638 2019-05-31                 1580        2212          2212.0
# 38697 2019-06-03                 1760        2464          2464.0
# 38700 2019-06-03                 1580        2212          2212.0
# 38739 2019-06-04                 1320        1848          1848.0
# 38766 2019-06-04                 1720        2408          2408.0
# 39436 2019-06-19                 1660        2324          2324.0
# 39441 2019-06-19                 1440        2016          2016.0
# 39702 2019-06-26                  220         308           308.0
# 39729 2019-06-26                  260         364           364.0
# 39899 2019-06-28                  800        1120          1120.0
# 39903 2019-06-28                  340         476           476.0
# 40120 2019-07-04                 1340        1876          1876.0
# 40146 2019-07-05                  380         532           532.0
# 40524 2019-07-15                  500         700           700.0
# 40549 2019-07-16                  700         980           980.0
# 40684 2019-07-18                  600         840           840.0
# 40810 2019-07-22                 1700        2380          2380.0
# 40839 2019-07-22                  300         420           420.0
# 40955 2019-07-24                 1660        2324          2324.0
# 41109 2019-07-26                  600         840           840.0
# 41187 2019-07-30                 1700        2380          2380.0
# 41253 2019-07-31                  460         644           644.0
# 41426 2019-08-05                 1040        1456          1456.0
# 41548 2019-08-06                  200         280           280.0
# 41743 2019-08-09                 1220        1708          1708.0
# 41790 2019-08-12                  780        1092          1092.0
#
#        TransStationeryType  Cumulative_RQ  Dates_ordinal
# 102                     17            860         736332
# 130                     17           1580         736333
# 134                     17           2420         736333
# 166                     17           3160         736333
# 233                     17           3740         736334
# 342                     17           5180         736338
# 489                     17           6080         736340
# 508                     17           6440         736341
# 519                     17           7420         736341
# 660                     17           9200         736345
# 903                     17           9520         736349
# 944                     17          10120         736349
# 1001                    17          10960         736352
# 1005                    17          12440         736352
# 1045                    17          13940         736353
# 1193                    17          15580         736355
# 1228                    17          17280         736355
# 1293                    17          18060         736356
# 1629                    17          19500         736366
# 1660                    17          20780         736366
# 1728                    17          21500         736367
# 1770                    17          23480         736368
# 2028                    17          23680         736374
# 2040                    17          25360         736374
# 2076                    17          26200         736375
# 2269                    17          27180         736381
# 2282                    17          28020         736381
# 2447                    17          29000         736383
# 2448                    17          29660         736383
# 2453                    17          31140         736384
# ...                    ...            ...            ...
# 38287                   17         412900         737202
# 38479                   17         413980         737207
# 38521                   17         414480         737208
# 38617                   17         414860         737209
# 38638                   17         416440         737210
# 38697                   17         418200         737213
# 38700                   17         419780         737213
# 38739                   17         421100         737214
# 38766                   17         422820         737214
# 39436                   17         424480         737229
# 39441                   17         425920         737229
# 39702                   17         426140         737236
# 39729                   17         426400         737236
# 39899                   17         427200         737238
# 39903                   17         427540         737238
# 40120                   17         428880         737244
# 40146                   17         429260         737245
# 40524                   17         429760         737255
# 40549                   17         430460         737256
# 40684                   17         431060         737258
# 40810                   17         432760         737262
# 40839                   17         433060         737262
# 40955                   17         434720         737264
# 41109                   17         435320         737266
# 41187                   17         437020         737270
# 41253                   17         437480         737271
# 41426                   17         438520         737276
# 41548                   17         438720         737277
# 41743                   17         439940         737280
# 41790                   17         440720         737283
#
# [424 rows x 12 columns]

# %%
itemId_array = df_extracted['TempIndex'].unique()
itemId_array
# Out:
# array([39, 19, 90, 78, 55, 27, 68, 21, 53, 18, 15, 80, 40, 89, 48,  6, 71,
#        25,  5,  9, 79,  8, 70, 50, 16, 51, 65, 12, 22, 11, 72, 42, 41, 56,
#        75, 57, 61, 49,  3, 36, 37, 66, 87, 44, 74, 43, 47, 73, 59, 54, 64,
#         7, 86, 60, 52, 63, 67, 46, 35, 13,  2, 10, 26, 14, 58, 85, 17,  1,
#        38, 45, 76, 20, 82,  4, 69, 33, 81, 84, 30, 88, 29, 31, 62, 77, 83,
#        34, 32, 23, 24, 28], dtype=int64)

# %% [markdown]
# ## LR Model Training

# %%
class LRTraining:
    def __init__(self, InputName, InputNameForGraph, InputNameForScore, InputNameForRQ, InputNameForRD,InputYear,InputMonth,InputDay):
        self.InputName = InputName
        self.InputNameForGraph = InputNameForGraph
        self.InputNameForScore = InputNameForScore
        self.InputNameForRQ = InputNameForRQ
        self.InputNameForRD = InputNameForRD
        self.InputYear = InputYear
        self.InputMonth = InputMonth
        self.InputDay = InputDay
    
    def SelectByName(InputName):
        df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(InputName)] #display item with selected name
        df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) #add a cumulative requisition quantity column
        df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) #convert Dates from object to datetime
        return df_filterByValue
    
    def LinearRegressionGraph(InputNameForGraph):
        df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(InputNameForGraph)] 
        df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
        df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) 
        ax = sns.regplot(x='Dates_ordinal', y = 'Cumulative_RQ', data = df_filterByValue)
        ax.set_xlim(df_filterByValue['Dates_ordinal'].min() - 1, df_filterByValue['Dates_ordinal'].max() + 1)
        ax.set_ylim(0, df_filterByValue['Cumulative_RQ'].max() + 1)
        ax.set_xlabel('Time')
        ax.set_ylabel('Requisition Quantity')
        new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
        ax.set_xticklabels(new_labels)
        plt.xticks(rotation=45)
        return ax
    
    def LinearRegressionScore(InputNameForScore):
        df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(InputNameForScore)] 
        df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
        df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) 
        X = df_filterByValue[['Dates_ordinal']]
        y = df_filterByValue['Cumulative_RQ']
        X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
        linReg = LinearRegression()
        linReg.fit(X_train, y_train)
        y_prep = linReg.predict(X_test)
        the_score = r2_score(y_test, y_prep)
        return the_score
    
    def EstimateRequisitionQuantity(InputYear,InputMonth,InputDay,InputNameForRQ):
        df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(InputNameForRQ)] 
        df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
        df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) 
        input_date = date(InputYear,InputMonth,InputDay)
        input_date_ordinal = input_date.toordinal()
        X = df_filterByValue[['Dates_ordinal']]
        y = df_filterByValue['Cumulative_RQ']
        X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
        linReg = LinearRegression()
        linReg.fit(X_train, y_train)
        requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
        quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
        requisition_msg_1 = 'May not receive ANY requisition by this date!'
        requisition_msg_2 = 'Estimated requisition quantity: '
        if(quantity_difference > 0):
            return requisition_msg_2 + str(int(quantity_difference)) + ' original quantity: ' + str(df_filterByValue.iloc[-1,8]) + ' Predicted quantity: ' + str(requisition_quantity_prediction)
        else:
            return requisition_msg_1
        
    def NextRequisitionDay(InputNameForRD):
        df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(InputNameForRD)] 
        df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
        df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) 
        latest_requisition_quantity = df_filterByValue.iloc[-1,8]
        latest_requisition_date = df_filterByValue.iloc[-1,9]
        estimate_next_requisition = latest_requisition_date
        X = df_filterByValue[['Dates_ordinal']]
        y = df_filterByValue['Cumulative_RQ']
        X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
        linReg = LinearRegression()
        linReg.fit(X_train, y_train)
        current_requisition_quantity = linReg.predict([[estimate_next_requisition]])
        if(current_requisition_quantity <= latest_requisition_quantity):
            while(current_requisition_quantity <= latest_requisition_quantity):
                estimate_next_requisition = estimate_next_requisition +1
                current_requisition_quantity = linReg.predict([[estimate_next_requisition]])
            return date.fromordinal(estimate_next_requisition)
        else: 
            return 'You should receive requisition by Now!'

    def EstimateAllRequisitionQuantity(InputYear,InputMonth,InputDay):
        itemId_array = df_extracted['TempIndex'].unique()
        itemCode_array = df_extracted['ItemNumber'].unique()
        itemSelectDateRQ_list = []
        itemOneMonthRQ_list = []
        itemDate_list = []
        itemMonthEndDate_list = []
        itemSelectedDate_list =[]
        for item in itemCode_array:
            df_filterByValue = df_extracted[df_extracted['ItemNumber'].str.match(item)] 
            df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) 
            df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) 
            input_date = date(InputYear,InputMonth,InputDay)
            if(InputMonth == 4) or (InputMonth == 6) or (InputMonth == 9) or (InputMonth == 11):
                input_date_ordinal = input_date.toordinal()
                final_firstdayofmonth = date(InputYear,InputMonth,1)
                final_firstdayofmonth_ordinal = final_firstdayofmonth.toordinal()
                final_lastdayofmonth = date(InputYear,InputMonth,30)
                final_lastdayofmonth_ordinal = final_lastdayofmonth.toordinal()
                X = df_filterByValue[['Dates_ordinal']]
                y = df_filterByValue['Cumulative_RQ']
                X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
                linReg = LinearRegression()
                linReg.fit(X_train, y_train)
                requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
                requisition_quantity_prediction_on_firstdayofmonth = linReg.predict([[final_firstdayofmonth_ordinal]])
                requisition_quantity_prediction_on_lastdayofmonth = linReg.predict([[final_lastdayofmonth_ordinal]])
#                 quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
#                 one_Month_RQprediction = linReg.predict([[df_filterByValue.iloc[-1,9]+29]])
#                 one_Month_RQ_difference = one_Month_RQprediction - df_filterByValue.iloc[-1,8]
                one_Month_RQ_difference = requisition_quantity_prediction_on_lastdayofmonth - requisition_quantity_prediction_on_firstdayofmonth
                requisition_msg_1 = '0'

#                 if(quantity_difference > 0):
#                     itemSelectDateRQ_list.append(str(int(quantity_difference)))
#                 else:
#                     itemSelectDateRQ_list.append(requisition_msg_1)
                if(one_Month_RQ_difference > 0):
                    itemOneMonthRQ_list.append(str(int(one_Month_RQ_difference)))
                else:
                    itemOneMonthRQ_list.append(requisition_msg_1)
                itemDate_list.append(str(final_firstdayofmonth))
                itemMonthEndDate_list.append(str(final_lastdayofmonth))
                itemSelectedDate_list.append(str(date.fromordinal(input_date_ordinal)))
            elif(InputMonth == 1) or (InputMonth == 3) or (InputMonth == 5) or (InputMonth == 7) or (InputMonth == 8) or (InputMonth == 10) or (InputMonth == 12):
                input_date_ordinal = input_date.toordinal()
                final_firstdayofmonth = date(InputYear,InputMonth,1)
                final_firstdayofmonth_ordinal = final_firstdayofmonth.toordinal()
                final_lastdayofmonth = date(InputYear,InputMonth,31)
                final_lastdayofmonth_ordinal = final_lastdayofmonth.toordinal()
                X = df_filterByValue[['Dates_ordinal']]
                y = df_filterByValue['Cumulative_RQ']
                X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
                linReg = LinearRegression()
                linReg.fit(X_train, y_train)
                requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
                requisition_quantity_prediction_on_firstdayofmonth = linReg.predict([[final_firstdayofmonth_ordinal]])
                requisition_quantity_prediction_on_lastdayofmonth = linReg.predict([[final_lastdayofmonth_ordinal]])
#                 quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
#                 one_Month_RQprediction = linReg.predict([[df_filterByValue.iloc[-1,9]+30]])
#                 one_Month_RQ_difference = one_Month_RQprediction - df_filterByValue.iloc[-1,8]
                one_Month_RQ_difference = requisition_quantity_prediction_on_lastdayofmonth - requisition_quantity_prediction_on_firstdayofmonth
                requisition_msg_1 = '0'

#                 if(quantity_difference > 0):
#                     itemSelectDateRQ_list.append(str(int(quantity_difference)))
#                 else:
#                     itemSelectDateRQ_list.append(requisition_msg_1)
                if(one_Month_RQ_difference > 0):
                    itemOneMonthRQ_list.append(str(int(one_Month_RQ_difference)))
                else:
                    itemOneMonthRQ_list.append(requisition_msg_1)
                itemDate_list.append(str(final_firstdayofmonth))
                itemMonthEndDate_list.append(str(final_lastdayofmonth))
                itemSelectedDate_list.append(str(date.fromordinal(input_date_ordinal)))
            else:
                if(InputYear % 4 == 0):
                    input_date_ordinal = input_date.toordinal()
                    final_firstdayofmonth = date(InputYear,InputMonth,1)
                    final_firstdayofmonth_ordinal = final_firstdayofmonth.toordinal()
                    final_lastdayofmonth = date(InputYear,InputMonth,29)
                    final_lastdayofmonth_ordinal = final_lastdayofmonth.toordinal()
                    X = df_filterByValue[['Dates_ordinal']]
                    y = df_filterByValue['Cumulative_RQ']
                    X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
                    linReg = LinearRegression()
                    linReg.fit(X_train, y_train)
                    requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
                    requisition_quantity_prediction_on_firstdayofmonth = linReg.predict([[final_firstdayofmonth_ordinal]])
                    requisition_quantity_prediction_on_lastdayofmonth = linReg.predict([[final_lastdayofmonth_ordinal]])
#                     quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
#                     one_Month_RQprediction = linReg.predict([[df_filterByValue.iloc[-1,9]+28]])
#                     one_Month_RQ_difference = one_Month_RQprediction - df_filterByValue.iloc[-1,8]
                    one_Month_RQ_difference = requisition_quantity_prediction_on_lastdayofmonth - requisition_quantity_prediction_on_firstdayofmonth
                    requisition_msg_1 = '0'

#                     if(quantity_difference > 0):
#                         itemSelectDateRQ_list.append(str(int(quantity_difference)))
#                     else:
#                         itemSelectDateRQ_list.append(requisition_msg_1)
                    if(one_Month_RQ_difference > 0):
                        itemOneMonthRQ_list.append(str(int(one_Month_RQ_difference)))
                    else:
                        itemOneMonthRQ_list.append(requisition_msg_1)
                    itemDate_list.append(str(final_firstdayofmonth))
                    itemMonthEndDate_list.append(str(final_lastdayofmonth))
                    itemSelectedDate_list.append(str(date.fromordinal(input_date_ordinal)))
                else:
                    input_date_ordinal = input_date.toordinal()
                    final_firstdayofmonth = date(InputYear,InputMonth,1)
                    final_firstdayofmonth_ordinal = final_firstdayofmonth.toordinal()
                    final_lastdayofmonth = date(InputYear,InputMonth,28)
                    final_lastdayofmonth_ordinal = final_lastdayofmonth.toordinal()
                    X = df_filterByValue[['Dates_ordinal']]
                    y = df_filterByValue['Cumulative_RQ']
                    X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
                    linReg = LinearRegression()
                    linReg.fit(X_train, y_train)
                    requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
                    requisition_quantity_prediction_on_firstdayofmonth = linReg.predict([[final_firstdayofmonth_ordinal]])
                    requisition_quantity_prediction_on_lastdayofmonth = linReg.predict([[final_lastdayofmonth_ordinal]])
#                     quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
#                     one_Month_RQprediction = linReg.predict([[df_filterByValue.iloc[-1,9]+27]])
#                     one_Month_RQ_difference = one_Month_RQprediction - df_filterByValue.iloc[-1,8]
                    one_Month_RQ_difference = requisition_quantity_prediction_on_lastdayofmonth - requisition_quantity_prediction_on_firstdayofmonth
                    requisition_msg_1 = '0'

#                     if(quantity_difference > 0):
#                         itemSelectDateRQ_list.append(str(int(quantity_difference)))
#                     else:
#                         itemSelectDateRQ_list.append(requisition_msg_1)
                    if(one_Month_RQ_difference > 0):
                        itemOneMonthRQ_list.append(str(int(one_Month_RQ_difference)))
                    else:
                        itemOneMonthRQ_list.append(requisition_msg_1)
                    itemDate_list.append(str(final_firstdayofmonth))
                    itemMonthEndDate_list.append(str(final_lastdayofmonth))
                    itemSelectedDate_list.append(str(date.fromordinal(input_date_ordinal)))
            
        itemRQ_array = np.asarray(itemSelectDateRQ_list)
        itemOneMonthRQ_array = np.asarray(itemOneMonthRQ_list)
        itemDate_array = np.asarray(itemDate_list)
        itemMonthEndDate_array = np.asarray(itemMonthEndDate_list)
        itemSelectedDate_array = np.asarray(itemSelectedDate_list)
        df_AllRQ = pd.DataFrame({'Id':itemId_array,'Reorder level and quantity': itemOneMonthRQ_array})
 #       df_AllRQ['Reorder level and quantity'] = itemOneMonthRQ_array
#        df_AllRQ['Last day of the Month'] = itemMonthEndDate_array
#        df_AllRQ['1st Day of the Moneth'] = itemDate_array
#        df_AllRQ['Estimated One Day Requisition Quantity'] = itemOneMonthRQ_array
#         df_AllRQ['Selected Requisition day'] = itemSelectedDate_array
#         df_AllRQ['Estimated Requisition Quantity'] = itemRQ_array
        return df_AllRQ

# %%
LRTraining.EstimateAllRequisitionQuantity(2019,9,16)
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Id Reorder level and quantity
# 0   39                       1592
# 1   19                       4139
# 2   90                        709
# 3   78                       1534
# 4   55                       4177
# 5   27                      11906
# 6   68                       1628
# 7   21                       3918
# 8   53                       3964
# 9   18                       3894
# 10  15                       1439
# 11  80                        706
# 12  40                       1545
# 13  89                        734
# 14  48                      35793
# 15   6                       2239
# 16  71                       1616
# 17  25                       7688
# 18   5                       2514
# 19   9                      32690
# 20  79                       1554
# 21   8                      28670
# 22  70                       1559
# 23  50                       4401
# 24  16                       1489
# 25  51                       3706
# 26  65                       3887
# 27  12                      32373
# 28  22                       3645
# 29  11                      29873
# ..  ..                        ...
# 60   2                       2404
# 61  10                      30077
# 62  26                       8789
# 63  14                      30215
# 64  58                       4138
# 65  85                      13402
# 66  17                       3840
# 67   1                       2313
# 68  38                       1515
# 69  45                       4615
# 70  76                       1528
# 71  20                       3547
# 72  82                        777
# 73   4                       2432
# 74  69                       1568
# 75  33                      12012
# 76  81                        826
# 77  84                      32628
# 78  30                      10728
# 79  88                      30996
# 80  29                      12082
# 81  31                      11754
# 82  62                       4363
# 83  77                       1583
# 84  83                      16351
# 85  34                       6113
# 86  32                      12082
# 87  23                       3645
# 88  24                       3803
# 89  28                      11054
#
# [90 rows x 2 columns]

# %%
LRTraining.EstimateRequisitionQuantity(2019,8,15,'Envelope Brown 5inchx7inch')
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 'Estimated requisition quantity: 2093668 original quantity: 952.0 Predicted quantity: [2094620.62037635]'

# %%
LRT = LRTraining
pickle.dump(LRT, open('LogicDataOne.pkl', 'wb'))

# %%
'Most Recent Requisition Date': itemDate_array, 'One Day Prediction': itemOneDayRQ_array, 'Selected Requisition day': itemSelectedDate_array,
# Out:
#   File "<ipython-input-17-463bc0fe503f>", line 1
#     'Most Recent Requisition Date': itemDate_array, 'One Day Prediction': itemOneDayRQ_array, 'Selected Requisition day': itemSelectedDate_array,
#                                                   ^
# SyntaxError: invalid syntax

# %%
'Estimated Requisition Quantity': itemRQ_array
