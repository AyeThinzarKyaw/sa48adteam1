# %% [markdown]
# # Machine Learning Documentation

# %% [markdown]
# ## Load Data

# %%
#import relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import date
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression

# %%
#loading data
df = pd.read_csv('MockDataV2.csv')
df.head()
# Out:
#    Index  TempIndex ItemNumber StationeryType            StationeryName  \
# 0      1         30      F032           File      Folder Plastic Clear
# 1      2         42      P011            Pad   Pad Postit Memo 1/2"x1"
# 2      3         86      T023       Tparency          Transparency Red
# 3      4         54      P034            Pen         Pen Felt Tip Blue
# 4      5          3      C003           Clip         Clips Double 3/4"
#
#    ReorderLevel ReorderQty      UOM  Price SupplierName  \
# 0           200    $150.00    Each     4.0        BANES
# 1           100     $60.00  Packet     3.4        CHEAP
# 2           100    $200.00     Box     1.4      LOTCASH
# 3           100     $50.00   Dozen     2.5        APLHA
# 4            50     $30.00   Dozen     0.9       RANDOM
#
#                      Dates      Time  RequisitionQuantity TotalPrice
# 0  Monday, January 2, 2017  13:11:37                  300  $1,200.00
# 1  Monday, January 2, 2017  10:43:02                  432  $1,468.80
# 2  Monday, January 2, 2017  13:22:55                 1560  $2,184.00
# 3  Monday, January 2, 2017  16:58:29                  125    $312.50
# 4  Monday, January 2, 2017  11:31:16                  147    $132.30

# %%
#checking datatypes
df.dtypes
# Out:
# Index                    int64
# TempIndex                int64
# ItemNumber              object
# StationeryType          object
# StationeryName          object
# ReorderLevel             int64
# ReorderQty              object
# UOM                     object
# Price                  float64
# SupplierName            object
# Dates                   object
# Time                    object
# RequisitionQuantity      int64
# TotalPrice              object
# dtype: object

# %% [markdown]
# ### Data Pre-processing

# %%
#adding a new column(TotalPrice_new) for converting TotalPrice into datatype float64.
df['TotalPrice_new'] = df['TotalPrice'].apply(lambda x: x.replace('$','')).apply(lambda x: x.replace(',','')).astype(np.float64)
df
# Out:
#       Index  TempIndex ItemNumber StationeryType  \
# 0         1         30      F032           File
# 1         2         42      P011            Pad
# 2         3         86      T023       Tparency
# 3         4         54      P034            Pen
# 4         5          3      C003           Clip
# 5         6         90       T101          Tray
# 6         7         79      S023        Stapler
# 7         8         85      T022       Tparency
# 8         9         60      P040            Pen
# 9        10         46      P015            Pad
# 10       11         11      E005       Envelope
# 11       12         26      F022           File
# 12       13         12      E006       Envelope
# 13       14         42      P011            Pad
# 14       15         15      E020         Eraser
# 15       16          2      C002           Clip
# 16       17         10      E004       Envelope
# 17       18         47      P016            Pad
# 18       19         68      R001          Ruler
# 19       20         25      F021           File
# 20       21         24      F020           File
# 21       22         24      F020           File
# 22       23         38      H031        Puncher
# 23       24         75      S012      Shorthand
# 24       25         60      P040            Pen
# 25       26         78      S022        Stapler
# 26       27         65      P045            Pen
# 27       28          4      C004           Clip
# 28       29          7      E001       Envelope
# 29       30         63      P043            Pen
# ...     ...        ...        ...            ...
# 5370   5371         71      S041           Tape
# 5371   5372         35      H012            Pen
# 5372   5373         34      H011            Pen
# 5373   5374         52      P032            Pen
# 5374   5375         13      E007       Envelope
# 5375   5376         79      S023        Stapler
# 5376   5377         12      E006       Envelope
# 5377   5378         15      E020         Eraser
# 5378   5379         86      T023       Tparency
# 5379   5380         64      P044            Pen
# 5380   5381         16      E021         Eraser
# 5381   5382         80      T001          Tacks
# 5382   5383         79      S023        Stapler
# 5383   5384         75      S012      Shorthand
# 5384   5385         87      T024       Tparency
# 5385   5386         63      P043            Pen
# 5386   5387         89      T100           Tray
# 5387   5388         15      E020         Eraser
# 5388   5389         64      P044            Pen
# 5389   5390         18      E031       Exercise
# 5390   5391         84      T021       Tparency
# 5391   5392         80      T001          Tacks
# 5392   5393         31      F033           File
# 5393   5394         34      H011            Pen
# 5394   5395         45      P014            Pad
# 5395   5396         48      P020          Paper
# 5396   5397         47      P016            Pad
# 5397   5398         11      E005       Envelope
# 5398   5399         77      S021        Stapler
# 5399   5400          3      C003           Clip
#
#                          StationeryName  ReorderLevel ReorderQty      UOM  \
# 0                 Folder Plastic Clear            200    $150.00    Each
# 1              Pad Postit Memo 1/2"x1"            100     $60.00  Packet
# 2                     Transparency Red            100    $200.00     Box
# 3                    Pen Felt Tip Blue            100     $50.00   Dozen
# 4                    Clips Double 3/4"             50     $30.00   Dozen
# 5                   Trays White In/Out             20     $10.00     Set
# 6                       Stapler No. 36             50     $20.00     Box
# 7                   Transparency Green            100    $200.00     Box
# 8          Pen Whiteboard Marker Green            100     $50.00     Box
# 9                Pad Postit Memo 2"x4"            100     $60.00  Packet
# 10              Envelope White (3"x6")            600    $400.00    Each
# 11                 File-Blue with Logo            200    $100.00    Each
# 12    Envelope White (3"x6") w/ Window            600    $400.00    Each
# 13             Pad Postit Memo 1/2"x1"            100     $60.00  Packet
# 14                       Eraser (hard)             50     $20.00    Each
# 15                     Clips Double 2"             50     $30.00   Dozen
# 16    Envelope Brown (5"x7") w/ Window            600    $400.00    Each
# 17             Pad Postit Memo 3/4"x2"            100     $60.00  Packet
# 18                            Ruler 6"             50     $20.00   Dozen
# 19                     File-Blue Plain            200    $100.00    Each
# 20                      File Separator            100     $50.00     Set
# 21                      File Separator            100     $50.00     Set
# 22                Hole Puncher 2 holes             50     $20.00    Each
# 23              Shorthand Book (80 pg)            100     $80.00    Each
# 24         Pen Whiteboard Marker Green            100     $50.00     Box
# 25                      Stapler No. 28             50     $20.00     Box
# 26                            Pencil B            100     $50.00   Dozen
# 27                   Clips Paper Large             50     $30.00     Box
# 28              Envelope Brown (3"x6")            600    $400.00    Each
# 29           Pencil 2B with Eraser End            100     $50.00   Dozen
# ...                                 ...           ...        ...      ...
# 5370             Scotch Tape Dispenser             50     $20.00    Each
# 5371                 Highlighter Green            100     $80.00     Box
# 5372                  Highlighter Blue            100     $80.00     Box
# 5373                 Pen Ballpoint Red            100     $50.00   Dozen
# 5374            Envelope White (5"x7")            600    $400.00    Each
# 5375                    Stapler No. 36             50     $20.00     Box
# 5376  Envelope White (3"x6") w/ Window            600    $400.00    Each
# 5377                     Eraser (hard)             50     $20.00    Each
# 5378                  Transparency Red            100    $200.00     Box
# 5379                         Pencil 4H            100     $50.00   Dozen
# 5380                     Eraser (soft)             50     $20.00    Each
# 5381                 Thumb Tacks Large             10     $10.00     Box
# 5382                    Stapler No. 36             50     $20.00     Box
# 5383            Shorthand Book (80 pg)            100     $80.00    Each
# 5378                 1220   $1,708.00          1708.0
# 5379                  155     $356.50           356.5
# 5380                   52      $15.60            15.6
# 5381                   30      $60.00            60.0
# 5382                  150     $585.00           585.0
# 5383                  392     $156.80           156.8
# 5384                 1080   $1,512.00          1512.0
# 5385                  390     $702.00           702.0
# 5386                   56     $336.00           336.0
# 5387                  140      $56.00            56.0
# 5388                  285     $655.50           655.5
# 5389                  315      $81.90            81.9
# 5390                  560     $784.00           784.0
# 5391                   54     $108.00           108.0
# 5392                 1185   $4,740.00          4740.0
# 5393                  240   $1,344.00          1344.0
# 5394                  216   $1,339.20          1339.2
# 5395                 3300  $42,900.00         42900.0
# 5396                  468   $2,901.60          2901.6
# 5397                 1120   $1,120.00          1120.0
# 5398                   44     $171.60           171.6
# 5399                  288     $259.20           259.2
#
# [5400 rows x 15 columns]

# %%
#extract the necessary columns
df_extracted = df.iloc[:,[3,4,9,10,12,13,14]]
df_extracted.head()
# Out:
#   StationeryType            StationeryName SupplierName  \
# 0          File      Folder Plastic Clear         BANES
# 1           Pad   Pad Postit Memo 1/2"x1"         CHEAP
# 2      Tparency          Transparency Red       LOTCASH
# 3           Pen         Pen Felt Tip Blue         APLHA
# 4          Clip         Clips Double 3/4"        RANDOM
#
#                      Dates  RequisitionQuantity TotalPrice  TotalPrice_new
# 0  Monday, January 2, 2017                  300  $1,200.00          1200.0
# 1  Monday, January 2, 2017                  432  $1,468.80          1468.8
# 2  Monday, January 2, 2017                 1560  $2,184.00          2184.0
# 3  Monday, January 2, 2017                  125    $312.50           312.5
# 4  Monday, January 2, 2017                  147    $132.30           132.3

# %%
df_extracted['Dates'] = df_extracted['Dates'].astype('datetime64[ns]')
df_extracted
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      StationeryType                     StationeryName SupplierName  \
# 0             File               Folder Plastic Clear         BANES
# 1              Pad            Pad Postit Memo 1/2"x1"         CHEAP
# 2         Tparency                   Transparency Red       LOTCASH
# 3              Pen                  Pen Felt Tip Blue         APLHA
# 4             Clip                  Clips Double 3/4"        RANDOM
# 5             Tray                 Trays White In/Out         APLHA
# 6          Stapler                     Stapler No. 36         OMEGA
# 7         Tparency                 Transparency Green       LOTCASH
# 8              Pen        Pen Whiteboard Marker Green     FANTASTIC
# 9              Pad              Pad Postit Memo 2"x4"           ISS
# 10        Envelope             Envelope White (3"x6")           ISS
# 11            File                File-Blue with Logo           WOW
# 12        Envelope   Envelope White (3"x6") w/ Window         OMEGA
# 13             Pad            Pad Postit Memo 1/2"x1"         CHEAP
# 14          Eraser                      Eraser (hard)       LOTCASH
# 15            Clip                    Clips Double 2"         BANES
# 16        Envelope   Envelope Brown (5"x7") w/ Window           ISS
# 17             Pad            Pad Postit Memo 3/4"x2"           ISS
# 18           Ruler                           Ruler 6"         APLHA
# 19            File                    File-Blue Plain           ISS
# 20            File                     File Separator         OMEGA
# 21            File                     File Separator         OMEGA
# 22         Puncher               Hole Puncher 2 holes         CHEAP
# 23       Shorthand             Shorthand Book (80 pg)         BANES
# 24             Pen        Pen Whiteboard Marker Green     FANTASTIC
# 25         Stapler                     Stapler No. 28         APLHA
# 26             Pen                           Pencil B       LOTCASH
# 27            Clip                  Clips Paper Large         APLHA
# 28        Envelope             Envelope Brown (3"x6")           ISS
# 29             Pen          Pencil 2B with Eraser End     FANTASTIC
# ...             ...                                ...          ...
# 5370          Tape              Scotch Tape Dispenser       LOTCASH
# 5371           Pen                  Highlighter Green           WOW
# 5372           Pen                   Highlighter Blue         OMEGA
# 5373           Pen                  Pen Ballpoint Red         CHEAP
# 5374      Envelope             Envelope White (5"x7")         APLHA
# 5375       Stapler                     Stapler No. 36         OMEGA
# 5376      Envelope   Envelope White (3"x6") w/ Window         OMEGA
# 5377        Eraser                      Eraser (hard)       LOTCASH
# 5378      Tparency                   Transparency Red       LOTCASH
# 5379           Pen                          Pencil 4H         APLHA
# 5380        Eraser                      Eraser (soft)         FIEND
# 5381         Tacks                  Thumb Tacks Large         BANES
# 5382       Stapler                     Stapler No. 36         OMEGA
# 5383     Shorthand             Shorthand Book (80 pg)         BANES
# 5384      Tparency          Transparency Reverse Blue     FANTASTIC
# 5385           Pen          Pencil 2B with Eraser End     FANTASTIC
# 5386          Tray                       Trays In/Out         CHEAP
# 5387        Eraser                      Eraser (hard)       LOTCASH
# 5388           Pen                          Pencil 4H         APLHA
# 5389      Exercise             Exercise Book (120 pg)         BANES
# 5390      Tparency                 Transparency Clear       LOTCASH
# 5391         Tacks                  Thumb Tacks Large         BANES
# 5392          File               Folder Plastic Green        RANDOM
# 5393           Pen                   Highlighter Blue         OMEGA
# 5394           Pad              Pad Postit Memo 2"x4"         APLHA
# 5395         Paper                 Paper Photostat A3         APLHA
# 5396           Pad            Pad Postit Memo 3/4"x2"           ISS
# 5397      Envelope             Envelope White (3"x6")           ISS
# 5398       Stapler                     Stapler No. 36         FIEND
# 5399          Clip                  Clips Double 3/4"        RANDOM
#
#           Dates  RequisitionQuantity  TotalPrice  TotalPrice_new
# 0    2017-01-02                  300   $1,200.00          1200.0
# 1    2017-01-02                  432   $1,468.80          1468.8
# 2    2017-01-02                 1560   $2,184.00          2184.0
# 3    2017-01-02                  125     $312.50           312.5
# 4    2017-01-02                  147     $132.30           132.3
# 5    2017-01-02                   87     $522.00           522.0
# 6    2017-01-02                   40     $156.00           156.0
# 7    2017-01-03                 1720   $2,408.00          2408.0
# 8    2017-01-03                  235   $1,692.00          1692.0
# 9    2017-01-03                  180   $1,116.00          1116.0
# 10   2017-01-03                  960     $960.00           960.0
# 11   2017-01-03                  600   $1,380.00          1380.0
# 12   2017-01-03                 2840   $3,124.00          3124.0
# 13   2017-01-03                  522   $1,774.80          1774.8
# 14   2017-01-03                   54      $21.60            21.6
# 15   2017-01-03                   75      $90.00            90.0
# 16   2017-01-03                  600   $1,020.00          1020.0
# 17   2017-01-03                   60     $372.00           372.0
# 18   2017-01-04                  156     $390.00           390.0
# 19   2017-01-04                  300     $690.00           690.0
# 20   2017-01-04                  225     $450.00           450.0
# 21   2017-01-04                  490     $980.00           980.0
# 22   2017-01-04                  110   $1,122.00          1122.0
# 23   2017-01-04                  520     $208.00           208.0
# 24   2017-01-04                   85     $612.00           612.0
# 25   2017-01-04                   64     $230.40           230.4
# 26   2017-01-04                  410     $410.00           410.0
# 27   2017-01-04                  300     $600.00           600.0
# 28   2017-01-04                 1240   $1,240.00          1240.0
# 29   2017-01-04                  160     $288.00           288.0
# ...         ...                  ...         ...             ...
# 5370 2018-12-27                  154     $354.20           354.2
# 5371 2018-12-27                  312   $1,747.20          1747.2
# 5372 2018-12-28                  288   $1,612.80          1612.8
# 5373 2018-12-28                  150     $375.00           375.0
# 5374 2018-12-28                 1680   $2,688.00          2688.0
# 5375 2018-12-28                   20      $78.00            78.0
# 5376 2018-12-28                 1960   $2,156.00          2156.0
# 5377 2018-12-28                  152      $60.80            60.8
# 5378 2018-12-28                 1220   $1,708.00          1708.0
# 5379 2018-12-28                  155     $356.50           356.5
# 5380 2018-12-28                   52      $15.60            15.6
# 5381 2018-12-28                   30      $60.00            60.0
# 5382 2018-12-28                  150     $585.00           585.0
# 5383 2018-12-28                  392     $156.80           156.8
# 5384 2018-12-28                 1080   $1,512.00          1512.0
# 5385 2018-12-28                  390     $702.00           702.0
# 5386 2018-12-28                   56     $336.00           336.0
# 5387 2018-12-31                  140      $56.00            56.0
# 5388 2018-12-31                  285     $655.50           655.5
# 5389 2018-12-31                  315      $81.90            81.9
# 5390 2018-12-31                  560     $784.00           784.0
# 5391 2018-12-31                   54     $108.00           108.0
# 5392 2018-12-31                 1185   $4,740.00          4740.0
# 5393 2018-12-31                  240   $1,344.00          1344.0
# 5394 2018-12-31                  216   $1,339.20          1339.2
# 5395 2018-12-31                 3300  $42,900.00         42900.0
# 5396 2018-12-31                  468   $2,901.60          2901.6
# 5397 2018-12-31                 1120   $1,120.00          1120.0
# 5398 2018-12-31                   44     $171.60           171.6
# 5399 2018-12-31                  288     $259.20           259.2
#
# [5400 rows x 7 columns]

# %%
df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 7 columns):
# StationeryType         5400 non-null object
# StationeryName         5400 non-null object
# SupplierName           5400 non-null object
# Dates                  5400 non-null datetime64[ns]
# RequisitionQuantity    5400 non-null int64
# TotalPrice             5400 non-null object
# TotalPrice_new         5400 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 295.4+ KB

# %%
#list down all the stationery types
TypeArray = df_extracted.StationeryType.unique()
TypeArray

#replace stationery type name with an integer 
def Trans_StationeryType(x):
    for y in range(0,len(TypeArray)):
        if x == TypeArray[y]:
            return y+1

#adding a new column for the stationery type in terms of integer
df_extracted['TransStationeryType'] = df_extracted['StationeryType'].apply(Trans_StationeryType)
df_extracted.head()
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#   StationeryType            StationeryName SupplierName      Dates  \
# 0          File      Folder Plastic Clear         BANES 2017-01-02
# 1           Pad   Pad Postit Memo 1/2"x1"         CHEAP 2017-01-02
# 2      Tparency          Transparency Red       LOTCASH 2017-01-02
# 3           Pen         Pen Felt Tip Blue         APLHA 2017-01-02
# 4          Clip         Clips Double 3/4"        RANDOM 2017-01-02
#
#    RequisitionQuantity TotalPrice  TotalPrice_new  TransStationeryType
# 0                  300  $1,200.00          1200.0                    1
# 1                  432  $1,468.80          1468.8                    2
# 2                 1560  $2,184.00          2184.0                    3
# 3                  125    $312.50           312.5                    4
# 4                  147    $132.30           132.3                    5

# %%
#groupby Stationery Name & Type & Supplier and sum the quantity and total price
df_new = df_extracted.groupby(['StationeryName','StationeryType','SupplierName']).agg({'RequisitionQuantity':'sum','TotalPrice_new':'sum'}) 
df_new
# Out:
#                                                                   RequisitionQuantity  \
# StationeryName                       StationeryType SupplierName
# Clips Double 1"                      Clip           FIEND                       10146
# Clips Double 2"                      Clip           BANES                        6924
# Clips Double 3/4"                    Clip           RANDOM                      10401
# Clips Paper Large                    Clip           APLHA                       11037
# Clips Paper Medium                   Clip           APLHA                        8508
# Clips Paper Small                    Clip           BANES                        8502
# Envelope Brown (3"x6")               Envelope       ISS                        100520
# Envelope Brown (3"x6") w/ Window     Envelope       OMEGA                      156040
# Envelope Brown (5"x7")               Envelope       LOTCASH                    152920
# Envelope Brown (5"x7") w/ Window     Envelope       ISS                        105720
# Envelope White (3"x6")               Envelope       ISS                        138360
# Envelope White (3"x6") w/ Window     Envelope       OMEGA                      146440
# Envelope White (5"x7")               Envelope       APLHA                      155840
# Envelope White (5"x7") w/ Window     Envelope       BANES                      159920
# Eraser (hard)                        Eraser         LOTCASH                      5692
# Eraser (soft)                        Eraser         FIEND                        6350
# Exercise Book (100 pg)               Exercise       OMEGA                       12360
# Exercise Book (120 pg)               Exercise       BANES                       14515
# Exercise Book A4 Hardcover (100 pg)  Exercise       WOW                         16955
# Exercise Book A4 Hardcover (120 pg)  Exercise       BANES                       19580
# Exercise Book A4 Hardcover (200 pg)  Exercise       BANES                       17895
# Exercise Book Hardcover (100 pg)     Exercise       BANES                       18660
# Exercise Book Hardcover (120 pg)     Exercise       ISS                         17910
# File Separator                       File           OMEGA                       16990
# File-Blue Plain                      File           ISS                         30850
# File-Blue with Logo                  File           WOW                         35860
# File-Brown w/o Logo                  File           APLHA                       39135
# File-Brown with Logo                 File           ISS                         53385
# Folder Plastic Blue                  File           OMEGA                       44280
# Folder Plastic Clear                 File           BANES                       42240
# ...                                                                               ...
# Pen Whiteboard Marker Red            Pen            FANTASTIC                   15935
# Pencil 2B                            Pen            CHEAP                       17455
# Pencil 2B with Eraser End            Pen            FANTASTIC                   12820
# Pencil 4H                            Pen            APLHA                       14940
# Pencil B                             Pen            LOTCASH                     15150
# Pencil B with Eraser End             Pen            LOTCASH                     18805
# Ruler 12"                            Ruler          FANTASTIC                    5806
# Ruler 6"                             Ruler          APLHA                        6350
# Scissors                             Scissors       LOTCASH                      6100
# Scotch Tape                          Tape           OMEGA                        5590
# Scotch Tape Dispenser                Tape           LOTCASH                      6494
# Sharpener                            Sharpener      APLHA                        6964
# Shorthand Book (100 pg)              Shorthand      FANTASTIC                   23464
# Shorthand Book (120 pg)              Shorthand      ISS                         25792
# Shorthand Book (80 pg)               Shorthand      BANES                       28368
# Stapler No. 28                       Stapler        APLHA                        7500
#                                                     CHEAP                        7768
# Stapler No. 36                       Stapler        FIEND                        6626
#                                                     OMEGA                        6864
# Thumb Tacks Large                    Tacks          BANES                        3603
# Thumb Tacks Medium                   Tacks          WOW                          3632
# Thumb Tacks Small                    Tacks          LOTCASH                      3660
# Transparency Blue                    Tparency       FANTASTIC                   79640
# Transparency Clear                   Tparency       LOTCASH                    131080
# Transparency Cover 3M                Tparency       FIEND                      140720
# Transparency Green                   Tparency       LOTCASH                     67120
# Transparency Red                     Tparency       LOTCASH                     54840
# Transparency Reverse Blue            Tparency       FANTASTIC                   66440
# Trays In/Out                         Tray           CHEAP                        3553
# Trays White In/Out                   Tray           APLHA                        3109
#
#                                                                   TotalPrice_new
# StationeryName                       StationeryType SupplierName
# Clips Double 1"                      Clip           FIEND               10146.00
# Clips Double 2"                      Clip           BANES                8308.80
# Clips Double 3/4"                    Clip           RANDOM               9360.90
# Clips Paper Large                    Clip           APLHA               22074.00
# Clips Paper Medium                   Clip           APLHA               12762.00
# Clips Paper Small                    Clip           BANES               10202.40
# Envelope Brown (3"x6")               Envelope       ISS                100520.00
# Envelope Brown (3"x6") w/ Window     Envelope       OMEGA              171644.00
# Envelope Brown (5"x7")               Envelope       LOTCASH            244672.00
# Envelope Brown (5"x7") w/ Window     Envelope       ISS                179724.00
# Envelope White (3"x6")               Envelope       ISS                138360.00
# Envelope White (3"x6") w/ Window     Envelope       OMEGA              161084.00
# Envelope White (5"x7")               Envelope       APLHA              249344.00
# Envelope White (5"x7") w/ Window     Envelope       BANES              271864.00
# Eraser (hard)                        Eraser         LOTCASH              2276.80
# Eraser (soft)                        Eraser         FIEND                1905.00
# Exercise Book (100 pg)               Exercise       OMEGA                2719.20
# Exercise Book (120 pg)               Exercise       BANES                3773.90
# Exercise Book A4 Hardcover (100 pg)  Exercise       WOW                  3560.55
# Exercise Book A4 Hardcover (120 pg)  Exercise       BANES                4307.60
# Exercise Book A4 Hardcover (200 pg)  Exercise       BANES                4831.65
# Exercise Book Hardcover (100 pg)     Exercise       BANES                9330.00
# Exercise Book Hardcover (120 pg)     Exercise       ISS                 10029.60
# File Separator                       File           OMEGA               33980.00
# File-Blue Plain                      File           ISS                 70955.00
# File-Blue with Logo                  File           WOW                 82478.00
# File-Brown w/o Logo                  File           APLHA               82183.50
# File-Brown with Logo                 File           ISS                122785.50
# Folder Plastic Blue                  File           OMEGA              177120.00
# Folder Plastic Clear                 File           BANES              168960.00
# ...                                                                          ...
# Pen Whiteboard Marker Red            Pen            FANTASTIC          114732.00
# Pencil 2B                            Pen            CHEAP               20946.00
# Pencil 2B with Eraser End            Pen            FANTASTIC           23076.00
# Pencil 4H                            Pen            APLHA               34362.00
# Pencil B                             Pen            LOTCASH             15150.00
# Pencil B with Eraser End             Pen            LOTCASH             22566.00
# Ruler 12"                            Ruler          FANTASTIC           20321.00
# Ruler 6"                             Ruler          APLHA               15875.00
# Scissors                             Scissors       LOTCASH             24400.00
# Scotch Tape                          Tape           OMEGA                6708.00
# Scotch Tape Dispenser                Tape           LOTCASH             14936.20
# Sharpener                            Sharpener      APLHA                6964.00
# Shorthand Book (100 pg)              Shorthand      FANTASTIC           11732.00
# Shorthand Book (120 pg)              Shorthand      ISS                 15475.20
# Shorthand Book (80 pg)               Shorthand      BANES               11347.20
# Stapler No. 28                       Stapler        APLHA               27000.00
#                                                     CHEAP               27964.80
# Stapler No. 36                       Stapler        FIEND               25841.40
#                                                     OMEGA               26769.60
# Thumb Tacks Large                    Tacks          BANES                7206.00
# Thumb Tacks Medium                   Tacks          WOW                  5448.00
# Thumb Tacks Small                    Tacks          LOTCASH              3660.00
# Transparency Blue                    Tparency       FANTASTIC          111496.00
# Transparency Clear                   Tparency       LOTCASH            183512.00
# Transparency Cover 3M                Tparency       FIEND              197008.00
# Transparency Green                   Tparency       LOTCASH             93968.00
# Transparency Red                     Tparency       LOTCASH             76776.00
# Transparency Reverse Blue            Tparency       FANTASTIC           93016.00
# Trays In/Out                         Tray           CHEAP               21318.00
# Trays White In/Out                   Tray           APLHA               18654.00
#
# [90 rows x 2 columns]

# %%
df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5400 entries, 0 to 5399
# Data columns (total 8 columns):
# StationeryType         5400 non-null object
# StationeryName         5400 non-null object
# SupplierName           5400 non-null object
# Dates                  5400 non-null datetime64[ns]
# RequisitionQuantity    5400 non-null int64
# TotalPrice             5400 non-null object
# TotalPrice_new         5400 non-null float64
# TransStationeryType    5400 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 337.6+ KB

# %% [markdown]
# ## Select Features

# %%
input_name = str(input()) #input stationery name
df_filterByValue = df_extracted[df_extracted['StationeryName'].str.match(input_name)] #display item with selected name
df_filterByValue['Cumulative_RQ'] = df_filterByValue['RequisitionQuantity'].cumsum(axis=0) #add a cumulative requisition quantity column
df_filterByValue
# Out:
# Scissors
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      StationeryType StationeryName SupplierName      Dates  \
# 121       Scissors       Scissors       LOTCASH 2017-01-18
# 172       Scissors       Scissors       LOTCASH 2017-01-26
# 292       Scissors       Scissors       LOTCASH 2017-02-10
# 416       Scissors       Scissors       LOTCASH 2017-02-27
# 426       Scissors       Scissors       LOTCASH 2017-02-28
# 484       Scissors       Scissors       LOTCASH 2017-03-07
# 505       Scissors       Scissors       LOTCASH 2017-03-09
# 527       Scissors       Scissors       LOTCASH 2017-03-13
# 734       Scissors       Scissors       LOTCASH 2017-04-07
# 773       Scissors       Scissors       LOTCASH 2017-04-13
# 872       Scissors       Scissors       LOTCASH 2017-04-26
# 1012      Scissors       Scissors       LOTCASH 2017-05-16
# 1027      Scissors       Scissors       LOTCASH 2017-05-17
# 1061      Scissors       Scissors       LOTCASH 2017-05-23
# 1089      Scissors       Scissors       LOTCASH 2017-05-25
# 1366      Scissors       Scissors       LOTCASH 2017-06-27
# 1492      Scissors       Scissors       LOTCASH 2017-07-14
# 1660      Scissors       Scissors       LOTCASH 2017-08-07
# 1748      Scissors       Scissors       LOTCASH 2017-08-18
# 1834      Scissors       Scissors       LOTCASH 2017-08-31
# 1891      Scissors       Scissors       LOTCASH 2017-09-07
# 1909      Scissors       Scissors       LOTCASH 2017-09-11
# 1922      Scissors       Scissors       LOTCASH 2017-09-12
# 2119      Scissors       Scissors       LOTCASH 2017-10-10
# 2141      Scissors       Scissors       LOTCASH 2017-10-12
# 2261      Scissors       Scissors       LOTCASH 2017-10-30
# 2309      Scissors       Scissors       LOTCASH 2017-11-06
# 2351      Scissors       Scissors       LOTCASH 2017-11-10
# 2448      Scissors       Scissors       LOTCASH 2017-11-27
# 2568      Scissors       Scissors       LOTCASH 2017-12-11
# 2714      Scissors       Scissors       LOTCASH 2017-12-29
# 2715      Scissors       Scissors       LOTCASH 2017-12-29
# 2789      Scissors       Scissors       LOTCASH 2018-01-10
# 2921      Scissors       Scissors       LOTCASH 2018-01-26
# 3335      Scissors       Scissors       LOTCASH 2018-03-29
# 3382      Scissors       Scissors       LOTCASH 2018-04-05
# 3626      Scissors       Scissors       LOTCASH 2018-05-09
# 3718      Scissors       Scissors       LOTCASH 2018-05-23
# 3720      Scissors       Scissors       LOTCASH 2018-05-23
# 3754      Scissors       Scissors       LOTCASH 2018-05-28
# 3892      Scissors       Scissors       LOTCASH 2018-06-14
# 3916      Scissors       Scissors       LOTCASH 2018-06-19
# 4044      Scissors       Scissors       LOTCASH 2018-07-06
# 4134      Scissors       Scissors       LOTCASH 2018-07-18
# 4691      Scissors       Scissors       LOTCASH 2018-09-28
# 4700      Scissors       Scissors       LOTCASH 2018-10-01
# 4804      Scissors       Scissors       LOTCASH 2018-10-16
# 4862      Scissors       Scissors       LOTCASH 2018-10-24
# 4910      Scissors       Scissors       LOTCASH 2018-10-30
# 5048      Scissors       Scissors       LOTCASH 2018-11-15
# 5065      Scissors       Scissors       LOTCASH 2018-11-19
# 5153      Scissors       Scissors       LOTCASH 2018-11-29
# 5179      Scissors       Scissors       LOTCASH 2018-12-04
# 5201      Scissors       Scissors       LOTCASH 2018-12-05
# 5224      Scissors       Scissors       LOTCASH 2018-12-07
# 5330      Scissors       Scissors       LOTCASH 2018-12-21
#
#       RequisitionQuantity TotalPrice  TotalPrice_new  TransStationeryType  \
# 121                    90    $360.00           360.0                   17
# 172                   114    $456.00           456.0                   17
# 292                    94    $376.00           376.0                   17
# 416                   184    $736.00           736.0                   17
# 426                   154    $616.00           616.0                   17
# 484                   140    $560.00           560.0                   17
# 505                    90    $360.00           360.0                   17
# 527                    80    $320.00           320.0                   17
# 734                   138    $552.00           552.0                   17
# 773                    44    $176.00           176.0                   17
# 872                   136    $544.00           544.0                   17
# 1012                   28    $112.00           112.0                   17
# 1027                  156    $624.00           624.0                   17
# 1061                  166    $664.00           664.0                   17
# 1089                   96    $384.00           384.0                   17
# 1366                   28    $112.00           112.0                   17
# 1492                   78    $312.00           312.0                   17
# 1660                  116    $464.00           464.0                   17
# 1748                  182    $728.00           728.0                   17
# 1834                  186    $744.00           744.0                   17
# 1891                  176    $704.00           704.0                   17
# 1909                  108    $432.00           432.0                   17
# 1922                   98    $392.00           392.0                   17
# 2119                  106    $424.00           424.0                   17
# 2141                   74    $296.00           296.0                   17
# 2261                   34    $136.00           136.0                   17
# 2309                   22     $88.00            88.0                   17
# 2351                  154    $616.00           616.0                   17
# 2448                   60    $240.00           240.0                   17
# 2568                   34    $136.00           136.0                   17
# 2714                   24     $96.00            96.0                   17
# 2715                   38    $152.00           152.0                   17
# 2789                  176    $704.00           704.0                   17
# 2921                  148    $592.00           592.0                   17
# 3335                  200    $800.00           800.0                   17
# 3382                   94    $376.00           376.0                   17
# 3626                  158    $632.00           632.0                   17
# 3718                   88    $352.00           352.0                   17
# 3720                   90    $360.00           360.0                   17
# 3754                   20     $80.00            80.0                   17
# 3892                  100    $400.00           400.0                   17
# 3916                  170    $680.00           680.0                   17
# 4044                  130    $520.00           520.0                   17
# 4134                   40    $160.00           160.0                   17
# 4691                   58    $232.00           232.0                   17
# 4700                  186    $744.00           744.0                   17
# 4804                   66    $264.00           264.0                   17
# 4862                  150    $600.00           600.0                   17
# 4910                  188    $752.00           752.0                   17
# 5048                   24     $96.00            96.0                   17
# 5065                   96    $384.00           384.0                   17
# 5153                  178    $712.00           712.0                   17
# 5179                   78    $312.00           312.0                   17
# 5201                  190    $760.00           760.0                   17
# 5224                  148    $592.00           592.0                   17
# 5330                   96    $384.00           384.0                   17
#
#       Cumulative_RQ
# 121              90
# 172             204
# 292             298
# 416             482
# 426             636
# 484             776
# 505             866
# 527             946
# 734            1084
# 773            1128
# 872            1264
# 1012           1292
# 1027           1448
# 1061           1614
# 1089           1710
# 1366           1738
# 1492           1816
# 1660           1932
# 1748           2114
# 1834           2300
# 1891           2476
# 1909           2584
# 1922           2682
# 2119           2788
# 2141           2862
# 2261           2896
# 2309           2918
# 2351           3072
# 2448           3132
# 2568           3166
# 2714           3190
# 2715           3228
# 2789           3404
# 2921           3552
# 3335           3752
# 3382           3846
# 3626           4004
# 3718           4092
# 3720           4182
# 3754           4202
# 3892           4302
# 3916           4472
# 4044           4602
# 4134           4642
# 4691           4700
# 4700           4886
# 4804           4952
# 4862           5102
# 4910           5290
# 5048           5314
# 5065           5410
# 5153           5588
# 5179           5666
# 5201           5856
# 5224           6004
# 5330           6100

# %% [markdown]
# ## Linear Regression Model

# %%
df_extracted['StationeryName'] = df_extracted['StationeryName'].astype(str)
df_extracted.head()
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   StationeryType            StationeryName SupplierName      Dates  \
# 0          File      Folder Plastic Clear         BANES 2017-01-02
# 1           Pad   Pad Postit Memo 1/2"x1"         CHEAP 2017-01-02
# 2      Tparency          Transparency Red       LOTCASH 2017-01-02
# 3           Pen         Pen Felt Tip Blue         APLHA 2017-01-02
# 4          Clip         Clips Double 3/4"        RANDOM 2017-01-02
#
#    RequisitionQuantity TotalPrice  TotalPrice_new  TransStationeryType
# 0                  300  $1,200.00          1200.0                    1
# 1                  432  $1,468.80          1468.8                    2
# 2                 1560  $2,184.00          2184.0                    3
# 3                  125    $312.50           312.5                    4
# 4                  147    $132.30           132.3                    5

# %%
df_filterByValue['Dates_ordinal'] = df_filterByValue['Dates'].apply(lambda date: date.toordinal()) #convert Dates from object to datetime
df_filterByValue
# Out:
# C:\Codingsoftware\Ananconda3\envs\sa48\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      StationeryType StationeryName SupplierName      Dates  \
# 121       Scissors       Scissors       LOTCASH 2017-01-18
# 172       Scissors       Scissors       LOTCASH 2017-01-26
# 292       Scissors       Scissors       LOTCASH 2017-02-10
# 416       Scissors       Scissors       LOTCASH 2017-02-27
# 426       Scissors       Scissors       LOTCASH 2017-02-28
# 484       Scissors       Scissors       LOTCASH 2017-03-07
# 505       Scissors       Scissors       LOTCASH 2017-03-09
# 527       Scissors       Scissors       LOTCASH 2017-03-13
# 734       Scissors       Scissors       LOTCASH 2017-04-07
# 773       Scissors       Scissors       LOTCASH 2017-04-13
# 872       Scissors       Scissors       LOTCASH 2017-04-26
# 1012      Scissors       Scissors       LOTCASH 2017-05-16
# 1027      Scissors       Scissors       LOTCASH 2017-05-17
# 1366                   28    $112.00           112.0                   17
# 1492                   78    $312.00           312.0                   17
# 1660                  116    $464.00           464.0                   17
# 1748                  182    $728.00           728.0                   17
# 1834                  186    $744.00           744.0                   17
# 1891                  176    $704.00           704.0                   17
# 1909                  108    $432.00           432.0                   17
# 1922                   98    $392.00           392.0                   17
# 2119                  106    $424.00           424.0                   17
# 2141                   74    $296.00           296.0                   17
# 2261                   34    $136.00           136.0                   17
# 2309                   22     $88.00            88.0                   17
# 2351                  154    $616.00           616.0                   17
# 2448                   60    $240.00           240.0                   17
# 2568                   34    $136.00           136.0                   17
# 2714                   24     $96.00            96.0                   17
# 2715                   38    $152.00           152.0                   17
# 2789                  176    $704.00           704.0                   17
# 2921                  148    $592.00           592.0                   17
# 3335                  200    $800.00           800.0                   17
# 3382                   94    $376.00           376.0                   17
# 3626                  158    $632.00           632.0                   17
# 3718                   88    $352.00           352.0                   17
# 3720                   90    $360.00           360.0                   17
# 3754                   20     $80.00            80.0                   17
# 3892                  100    $400.00           400.0                   17
# 3916                  170    $680.00           680.0                   17
# 4044                  130    $520.00           520.0                   17
# 4134                   40    $160.00           160.0                   17
# 4691                   58    $232.00           232.0                   17
# 4700                  186    $744.00           744.0                   17
# 4804                   66    $264.00           264.0                   17
# 4862                  150    $600.00           600.0                   17
# 4910                  188    $752.00           752.0                   17
# 5048                   24     $96.00            96.0                   17
# 5065                   96    $384.00           384.0                   17
# 5153                  178    $712.00           712.0                   17
# 5179                   78    $312.00           312.0                   17
# 5201                  190    $760.00           760.0                   17
# 5224                  148    $592.00           592.0                   17
# 5330                   96    $384.00           384.0                   17
#
#       Cumulative_RQ  Dates_ordinal
# 121              90         736347
# 172             204         736355
# 292             298         736370
# 416             482         736387
# 426             636         736388
# 484             776         736395
# 505             866         736397
# 527             946         736401
# 734            1084         736426
# 773            1128         736432
# 872            1264         736445
# 1012           1292         736465
# 1027           1448         736466
# 1061           1614         736472
# 1089           1710         736474
# 1366           1738         736507
# 1492           1816         736524
# 1660           1932         736548
# 1748           2114         736559
# 1834           2300         736572
# 1891           2476         736579
# 1909           2584         736583
# 1922           2682         736584
# 2119           2788         736612
# 2141           2862         736614
# 2261           2896         736632
# 2309           2918         736639
# 2351           3072         736643
# 2448           3132         736660
# 2568           3166         736674
# 2714           3190         736692
# 2715           3228         736692
# 2789           3404         736704
# 2921           3552         736720
# 3335           3752         736782
# 3382           3846         736789
# 3626           4004         736823
# 3718           4092         736837
# 3720           4182         736837
# 3754           4202         736842
# 3892           4302         736859
# 3916           4472         736864
# 4044           4602         736881
# 4134           4642         736893
# 4691           4700         736965
# 4700           4886         736968
# 4804           4952         736983
# 4862           5102         736991
# 4910           5290         736997
# 5048           5314         737013
# 5065           5410         737017
# 5153           5588         737027
# 5179           5666         737032
# 5201           5856         737033
# 5224           6004         737035
# 5330           6100         737049

# %%
#visualize linear regression 
# %matplotlib inline
ax = sns.regplot(x='Dates_ordinal', y = 'Cumulative_RQ', data = df_filterByValue)

ax.set_xlim(df_filterByValue['Dates_ordinal'].min() - 1, df_filterByValue['Dates_ordinal'].max() + 1)
ax.set_ylim(0, df_filterByValue['Cumulative_RQ'].max() + 1)

ax.set_xlabel('Time')
ax.set_ylabel('Requisition Quantity')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels)
plt.xticks(rotation=45)
# Out:
# (array([736300., 736400., 736500., 736600., 736700., 736800., 736900.,
#         737000., 737100.]), <a list of 9 Text xticklabel objects>)

# %%
X = df_filterByValue[['Dates_ordinal']]
y = df_filterByValue['Cumulative_RQ']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 0)
print(X_train.shape) # X_train and X_test shape should be 2D array
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (42, 1)
# (14, 1)
# (42,)
# (14,)

# %%
X_test
# Out:
#       Dates_ordinal
# 4700         736968
# 2921         736720
# 3892         736859
# 2309         736639
# 1012         736465
# 292          736370
# 2789         736704
# 4134         736893
# 4804         736983
# 2714         736692
# 426          736388
# 872          736445
# 2448         736660
# 1922         736584

# %%
linReg = LinearRegression()
linReg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(linReg.intercept_)
print(linReg.coef_)
# Out:
# -5565180.909712265
# [7.5585245]

# %%
y_prep = linReg.predict(X_test)
y_prep
# Out:
# array([5209.77420244, 3335.26012638, 4385.89503191, 2723.01964185,
#        1407.83637881,  689.77655128, 3214.32373437, 4642.88486492,
#        5323.15206995, 3123.62144037,  825.82999229, 1256.6658888 ,
#        2881.74865636, 2307.30079434])

# %%
mean_squared_error(y_test, y_prep)
# Out:
# 55787.20300180099

# %%
r2_score(y_test, y_prep)
# Out:
# 0.9749324213897609

# %%
input_year = int(input('Year: '))
input_month = int(input('Month: '))
input_day = int(input('Day: '))
input_date = date(input_year,input_month,input_day)
input_date
# Out:
# Year: 2019
# Month: 2
# Day: 14
# datetime.date(2019, 2, 14)

# %%
input_date_ordinal = input_date.toordinal()
input_date_ordinal
# Out:
# 737104

# %%
requisition_quantity_prediction = linReg.predict([[input_date_ordinal]])
quantity_difference = requisition_quantity_prediction - df_filterByValue.iloc[-1,8]
requisition_msg_1 = 'May not receive ANY requisition by this date!'
requisition_msg_2 = 'Estimated requisition quantity: '
if(quantity_difference > 0):
    print(requisition_msg_2 + str(int(quantity_difference)))
else:
    print(requisition_msg)
# Out:
# Estimated requisition quantity: 137

# %%
fig, ax = plt.subplots(figsize = (10,10))


ax.plot(X_test, y_prep, c = 'blue', label='Test data')
ax.scatter(X_test, y_prep, c = 'red', label='Test points')
ax.set(xlabel='Time', ylabel='Requisition Quantity')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels)
plt.xticks(rotation=45)
ax.grid()
plt.show()

# %%
latest_requisition_quantity = df_filterByValue.iloc[-1,8]
latest_requisition_quantity
# Out:
# 6100

# %%
latest_requisition_date = df_filterByValue.iloc[-1,9]
latest_requisition_date
# Out:
# 737049

# %%
estimate_next_requisition = latest_requisition_date
current_requisition_quantity = linReg.predict([[estimate_next_requisition]])

if(current_requisition_quantity <= latest_requisition_quantity):
    while(current_requisition_quantity <= latest_requisition_quantity):
        estimate_next_requisition = estimate_next_requisition +1
        current_requisition_quantity = linReg.predict([[estimate_next_requisition]])
else: 
    estimate_next_requisition

date.fromordinal(estimate_next_requisition)
# Out:
# datetime.date(2019, 1, 27)
